# %%
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
UNI = "cld2167"

# %%
def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((num_classes, y.shape[0]))
    y_one_hot[y, range(y.shape[0])] = 1
    return y_one_hot

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip().split("-")[1] for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0

    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)

# %%
# Load the data
data_root_path = 'cifar10-hw1/'
X_train_total, y_train_total = get_train_data(data_root_path) # this may take a few minutes
X_test = get_images(data_root_path + 'test')
print('Data loading done')
# Out:
# {'airplane': 0, 'automobile': 1, 'bird': 2, 'cat': 3, 'deer': 4, 'dog': 5, 'frog': 6, 'horse': 7, 'ship': 8, 'truck': 9}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %%
# X_train=X_train_total[:,:45000]
# X_val=X_train_total[:,45000:]
# y_train=y_train_total[:45000]
# y_val=y_train_total[45000:]

## probably best to train on EVERYTHING


X_train=X_train_total[:,:45000]
X_val=X_train_total[:,45000:]
y_train=y_train_total[:45000]
y_val=y_train_total[45000:]

# %%
def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((num_classes, y.shape[0]))
    y_one_hot[y, range(y.shape[0])] = 1
    return y_one_hot
print(y_train.shape)
y_train=one_hot(y_train)
y_val=one_hot(y_val)
print(y_train.shape)
# Out:
# (45000,)
# (10, 45000)

# %%
def get_batch(X_train,y_train,batch_size=100):
    ix = np.random.choice(X_train.shape[1], batch_size, replace=True)
    X_train_batch=X_train[:,ix]
    y_train_batch=y_train[:,ix]
    return X_train_batch.T,y_train_batch.T

# %%
X_train.shape
# Out:
# (3072, 45000)

# %%
def weight_variable(shape, name):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial, name=name)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

# %%
def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

# %%
#first conv layer


CONV_1_DEPTH = 64
CONV_1_SIZE = 5
CONV_2_DEPTH = 64
CONV_2_SIZE = 5
CONV_3_DEPTH = 64
CONV_3_SIZE = 3
CONV_4_DEPTH = 64
CONV_4_SIZE = 3
epsilon = 1e-3
FULLY_CONNECTED_SIZE = 1024

x = tf.placeholder(tf.float32, shape=[None, 3072], name="init_x")
y_ = tf.placeholder(tf.float32, shape=[None, 10], name="init_y")

W_conv1 = weight_variable([CONV_1_SIZE, CONV_1_SIZE, 3, CONV_1_DEPTH], name="conv_1_weights")
b_conv1 = bias_variable([CONV_1_DEPTH])
#x_image = tf.reshape(x, [-1, 28, 28, 1])


x_image = tf.reshape(x, [-1, CONV_1_DEPTH, CONV_1_DEPTH, 3])
conv_1 = conv2d(x_image, W_conv1) + b_conv1

batch_mean1, batch_var1 = tf.nn.moments(conv_1,[0])
scale1 = tf.Variable(tf.ones([64]))
beta1 = tf.Variable(tf.zeros([64]))
batch1 = tf.nn.batch_normalization(conv_1,batch_mean1,batch_var1,beta1,scale1,epsilon)

h_conv1 = tf.nn.relu(batch1)
h_pool1 = max_pool_2x2(h_conv1)

#second conv layer
W_conv2 = weight_variable([CONV_2_SIZE, CONV_2_SIZE, CONV_1_DEPTH, 64], name="conv_2_weights")
b_conv2 = bias_variable([64])
conv_2 = conv2d(h_pool1, W_conv2) + b_conv2

batch_mean2, batch_var2 = tf.nn.moments(conv_2,[0])
scale2 = tf.Variable(tf.ones([64]))
beta2 = tf.Variable(tf.zeros([64]))
batch2 = tf.nn.batch_normalization(conv_2,batch_mean2,batch_var2,beta2,scale2,epsilon)

h_conv2 = tf.nn.relu(batch2)
h_pool2 = max_pool_2x2(h_conv2)



#third conv layer
W_conv3 = weight_variable([CONV_3_SIZE, CONV_3_SIZE, CONV_3_DEPTH, 64], name="conv_3_weights")
b_conv3 = bias_variable([64])
conv_3 = conv2d(h_pool2, W_conv3) + b_conv3

batch_mean3, batch_var3 = tf.nn.moments(conv_3,[0])
scale3 = tf.Variable(tf.ones([64]))
beta3 = tf.Variable(tf.zeros([64]))
batch3 = tf.nn.batch_normalization(conv_3,batch_mean3,batch_var3,beta3,scale3,epsilon)

h_conv3 = tf.nn.relu(batch3)
h_pool3 = max_pool_2x2(h_conv3)


#fourth conv layer
W_conv4 = weight_variable([CONV_4_SIZE, CONV_4_SIZE, CONV_4_DEPTH, 64], name="conv_4_weights")
b_conv4 = bias_variable([64])
conv_4 = conv2d(h_pool3, W_conv4) + b_conv4

batch_mean4, batch_var4 = tf.nn.moments(conv_4,[0])
scale4 = tf.Variable(tf.ones([64]))
beta4 = tf.Variable(tf.zeros([64]))
batch4 = tf.nn.batch_normalization(conv_4,batch_mean4,batch_var4,beta4,scale4,epsilon)

h_conv4 = tf.nn.relu(batch4)
h_pool4 = max_pool_2x2(h_conv4)


#dense layer
W_fc1 = weight_variable([2 * 2 * 64, FULLY_CONNECTED_SIZE], name="first_fc")
b_fc1 = bias_variable([FULLY_CONNECTED_SIZE])

h_pool4_flat = tf.reshape(h_pool4, [-1, 2*2*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool4_flat, W_fc1) + b_fc1)


#readout
W_fc2 = weight_variable([FULLY_CONNECTED_SIZE, 10], name="last_fc")
b_fc2 = bias_variable([10])

y_conv = tf.matmul(h_fc1, W_fc2) + b_fc2

beta = 0.01
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))

# l2 regularization
regularizer = tf.nn.l2_loss(W_fc2) + tf.nn.l2_loss(W_fc1) + tf.nn.l2_loss(W_conv1) + tf.nn.l2_loss(W_conv2) + tf.nn.l2_loss(W_conv3) + tf.nn.l2_loss(W_conv4)
loss = tf.reduce_mean(cross_entropy + beta * regularizer)
#tf.summary.scalar("loss", loss)
#train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
train_step = tf.train.GradientDescentOptimizer(.5).minimize(loss)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

#tf.summary.scalar("accuracy", accuracy)

# merge all summaries into a single "operation" which we can execute in a session 
#summary_op = tf.merge_all_summaries()

with tf.Session() as sess:
    #sess = tf_debug.LocalCLIDebugWrapperSession(sess)
    sess.run(tf.global_variables_initializer())
    #writer = tf.summary.FileWriter("output", sess.graph)
    for i in range(10000):
    #    batch = mnist.train.next_batch(50)
        batch_x,batch_y = get_batch(X_train,y_train,batch_size=100)
        #print("batch x shape", batch_x.shape, batch_x.dtype)
        train_step.run(feed_dict={x: batch_x, y_: batch_y})
        
        # write log
        #writer.add_summary(summary, i)
        if i % 100 == 0:
            train_accuracy = accuracy.eval(feed_dict={x: batch_x, y_: batch_y})
            print('step %d, training accuracy %g' % (i, train_accuracy))
            print('test accuracy %g' % accuracy.eval(feed_dict={x: X_val.T, y_: y_val.T}))
    
    # network trained, now make predictions on the test set
    prediction = tf.argmax(y_conv,1)
    preds = prediction.eval(feed_dict={x: X_test.T})
    np.save("hw2_ans1_" + UNI + ".npy", preds)
# Out:
# step 0, training accuracy 0.13
# test accuracy 0.1058
# step 100, training accuracy 0.29
# test accuracy 0.1646
# step 200, training accuracy 0.28
# test accuracy 0.2252
# step 300, training accuracy 0.24
# test accuracy 0.24
# step 400, training accuracy 0.35
# test accuracy 0.256
# step 500, training accuracy 0.4
# test accuracy 0.2738
# step 600, training accuracy 0.37
# test accuracy 0.2876
# step 700, training accuracy 0.3
# test accuracy 0.2884
# step 800, training accuracy 0.39
# test accuracy 0.3032
# step 900, training accuracy 0.41
# test accuracy 0.3024
# step 1000, training accuracy 0.39
# test accuracy 0.3074
# step 1100, training accuracy 0.33
# test accuracy 0.3132
# step 1200, training accuracy 0.36
# test accuracy 0.3322
# step 1300, training accuracy 0.41
# test accuracy 0.3258
# step 1400, training accuracy 0.49
# test accuracy 0.3318
# step 1500, training accuracy 0.32
# test accuracy 0.331
# step 1600, training accuracy 0.43
# test accuracy 0.3264
# step 1700, training accuracy 0.44
# test accuracy 0.3516
# step 1800, training accuracy 0.52
# test accuracy 0.3834
# step 1900, training accuracy 0.42
# test accuracy 0.3684
# step 2000, training accuracy 0.33
# test accuracy 0.3982
# step 2100, training accuracy 0.49
# test accuracy 0.3332
# step 2200, training accuracy 0.51
# test accuracy 0.374
# step 2300, training accuracy 0.46
# test accuracy 0.4114
# step 2400, training accuracy 0.57
# test accuracy 0.4042
# step 2500, training accuracy 0.39
# test accuracy 0.376
# step 2600, training accuracy 0.5
# test accuracy 0.3772
# step 2700, training accuracy 0.48
# test accuracy 0.4236
# step 2800, training accuracy 0.52
# test accuracy 0.3968
# step 2900, training accuracy 0.47
# test accuracy 0.3796
# step 3000, training accuracy 0.49
# test accuracy 0.4272
# step 3100, training accuracy 0.48
# test accuracy 0.4352
# step 3200, training accuracy 0.56
# test accuracy 0.4018
# step 3300, training accuracy 0.59
# test accuracy 0.428
# step 3400, training accuracy 0.49
# test accuracy 0.4678
# step 3500, training accuracy 0.45
# test accuracy 0.4692
# step 3600, training accuracy 0.56
# test accuracy 0.4498
# step 3700, training accuracy 0.56
# test accuracy 0.448
# step 3800, training accuracy 0.58
# test accuracy 0.436
# step 3900, training accuracy 0.59
# test accuracy 0.4382
# step 4000, training accuracy 0.63
# test accuracy 0.449
# step 4100, training accuracy 0.69
# test accuracy 0.476
# step 4200, training accuracy 0.63
# test accuracy 0.4968
# step 4300, training accuracy 0.66
# test accuracy 0.4856
# step 4400, training accuracy 0.63
# test accuracy 0.493
# step 4500, training accuracy 0.58
# test accuracy 0.5028
# step 4600, training accuracy 0.62
# test accuracy 0.5086
# step 4700, training accuracy 0.55
# test accuracy 0.5026
# step 4800, training accuracy 0.71
# test accuracy 0.4858
# step 4900, training accuracy 0.68
# test accuracy 0.493
# step 5000, training accuracy 0.68
# test accuracy 0.52
# step 5100, training accuracy 0.61
# test accuracy 0.5034
# step 5200, training accuracy 0.62
# test accuracy 0.5354
# step 5300, training accuracy 0.69
# test accuracy 0.4454
# step 5400, training accuracy 0.68
# test accuracy 0.528
# step 5500, training accuracy 0.68
# test accuracy 0.557
# step 5600, training accuracy 0.58
# test accuracy 0.5174
# step 5700, training accuracy 0.63
# test accuracy 0.5298
# step 5800, training accuracy 0.65
# test accuracy 0.5072
# step 5900, training accuracy 0.63
# test accuracy 0.505
# step 6000, training accuracy 0.65
# test accuracy 0.4848
# step 6100, training accuracy 0.73
# test accuracy 0.5432
# step 6200, training accuracy 0.6
# test accuracy 0.5594
# step 6300, training accuracy 0.7
# test accuracy 0.5428
# step 6400, training accuracy 0.61
# test accuracy 0.5158
# step 6500, training accuracy 0.6
# test accuracy 0.5458
# step 6600, training accuracy 0.71
# test accuracy 0.5514
# step 6700, training accuracy 0.64
# test accuracy 0.577
# step 6800, training accuracy 0.74
# test accuracy 0.5768
# step 6900, training accuracy 0.76
# test accuracy 0.548
# step 7000, training accuracy 0.67
# test accuracy 0.5452
# step 7100, training accuracy 0.66
# test accuracy 0.5714
# step 7200, training accuracy 0.75
# test accuracy 0.5836
# step 7300, training accuracy 0.69
# test accuracy 0.5172
# step 7400, training accuracy 0.65
# test accuracy 0.5512
# step 7500, training accuracy 0.7
# test accuracy 0.5516
# step 7600, training accuracy 0.73
# test accuracy 0.577
# step 7700, training accuracy 0.66
# test accuracy 0.5604
# step 7800, training accuracy 0.71
# test accuracy 0.594
# step 7900, training accuracy 0.72
# test accuracy 0.5904
# step 8000, training accuracy 0.71
# test accuracy 0.5884
# step 8100, training accuracy 0.69
# test accuracy 0.5554
# step 8200, training accuracy 0.63
# test accuracy 0.6056
# step 8300, training accuracy 0.75
# test accuracy 0.5838
# step 8400, training accuracy 0.72
# test accuracy 0.5708
# step 8500, training accuracy 0.73
# test accuracy 0.5852
# step 8600, training accuracy 0.76
# test accuracy 0.563
# step 8700, training accuracy 0.74
# test accuracy 0.5744
# step 8800, training accuracy 0.76
# test accuracy 0.5958
# step 8900, training accuracy 0.62
# test accuracy 0.5982
# step 9000, training accuracy 0.76
# test accuracy 0.5854
# step 9100, training accuracy 0.71
# test accuracy 0.5978
# step 9200, training accuracy 0.81
# test accuracy 0.5744
# step 9300, training accuracy 0.72
# test accuracy 0.613
# step 9400, training accuracy 0.66
# test accuracy 0.566
# step 9500, training accuracy 0.79
# test accuracy 0.5946
# step 9600, training accuracy 0.72
# test accuracy 0.58
# step 9700, training accuracy 0.7
# test accuracy 0.5922
# step 9800, training accuracy 0.72
# test accuracy 0.6258
# step 9900, training accuracy 0.75
# test accuracy 0.5586
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-19c09f026ff4> in <module>()
#     127     preds = prediction.eval(feed_dict={x: X_test.T})
#     128     np.save("hw2_ans1_" + UNI + ".npy", preds)
# --> 129     writer.close()
#
# NameError: name 'writer' is not defined

# %%
preds
