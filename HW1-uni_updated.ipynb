# %% [markdown]
# # COMS 4995_002 Deep Learning Assignment 1
# Due on Monday, Oct 9, 11:59pm
#
# This assignment can be done in groups of at most 3 students. Everyone must submit on Courseworks individually.

# %% [markdown]
# Write down the UNIs of your group (if applicable)
#
# Member 1: Name, UNI
#
# Member 2: Name, UNI
#
# Member 3: Name, UNI

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
# you shouldn't need to make any more imports

# %%
class NeuralNetwork(object):
    """
    Abstraction of neural network.
    Stores parameters, activations, cached values. 
    Provides necessary functions for training and prediction. 
    """
    def __init__(self, layer_dimensions, drop_prob=0.0, reg_lambda=0.0):
        """
        Initializes the weights and biases for each layer
        :param layer_dimensions: (list) number of nodes in each layer
        :param drop_prob: drop probability for dropout layers. Only required in part 2 of the assignment
        :param reg_lambda: regularization parameter. Only required in part 2 of the assignment
        """
        
        eps = .01
        self.parameters = {'layer_dimensions':layer_dimensions, 'drop_prob':drop_prob, 'reg_lambda':reg_lambda} 
        self.num_layers = len(layer_dimensions)
        self.drop_prob = drop_prob
        self.reg_lambda = reg_lambda
        
        # init parameters
        for l in range(1, self.num_layers):
            self.parameters['W' + str(l)] = np.random.randn(layer_dimensions[l], layer_dimensions[l-1]) * eps
            self.parameters['b' + str(l)]= np.ones((layer_dimensions[l], 1))
    
        # print all params:
        print(self.parameters.keys())

        
#     def gradientCheck(self, theta, x):
#         eps = 1e-7
#         J_pos = J(theta + eps, x)
#         J_neg = J(theta - eps, x)
#         numerical_deriv = (J_pos - J-neg)/(2*eps)
#         analytic_deriv = JDeriv(theta, x)
#         error = norm(numerical_deriv-analyic_deriv)/norm()
#         return error
        
    def affineForward(self, A_, W_, b_):
        """
        Forward pass for the affine layer.
        :param A: input matrix, shape (L, S), where L is the number of hidden units in the previous layer and S is
        the number of samples
        :returns: the affine product WA + b, along with the cache required for the backward pass
        """
#         print("forward, shape W", W_.shape)
#         print("forward, shape A", A_.shape)
#         print("forward, shape b", b_.shape)
        return np.dot(W_, A_) + b_, [A_, W_, b_]
        

    def activationForward(self, A_, activation="relu"):
        """
        Common interface to access all activation functions.
        :param A: input to the activation function
        :param prob: activation funciton to apply to A. Just "relu" for this assignment.
        :returns: activation(A)
        """ 
        
        if activation == "relu":
            return self.relu(A_)
        if activation == "softmax":
            return self.softmax(A_)
        
        return A_

    def softmax(self, x):
        # softmax
        
        e_x = np.exp(x - np.max(x,axis=0))
        return e_x / e_x.sum( axis=0)
    
    def relu(self, X):
        return np.maximum(0,X)
            
    def dropout(self, A, prob):
        """
        :param A: 
        :param prob: drop prob
        :returns: tuple (A, M) 
            WHERE
            A is matrix after applying dropout
            M is dropout mask, used in the backward pass
        """
        
        # make a mask, binary mask
        # where that mask is 0, drop those activation units
        # where its one, scale them up by 1/(1-p)
        # in forward we need to apply this mask

        return A, M

    def forwardPropagation(self, X):
        """
        Runs an input X through the neural network to compute activations
        for all layers. Returns the output computed at the last layer along
        with the cache required for backpropagation.
        :returns: (tuple) AL, cache
            WHERE 
            AL is activation of last layer
            cache is cached values for each layer that
                     are needed in further steps
        """
        cache = {}
        A = X
        
        for l in range(1, self.num_layers):

            
            layer_cache = {}
            layer_cache["linear"] = [A,  self.parameters["W" + str(l)], self.parameters["b" + str(l)]]
            Z, cache_l = self.affineForward(A, self.parameters["W" + str(l)], self.parameters["b" + str(l)])
#             print("forward, layer", l)         
# #             print("forward shapes: Z, ", Z.shape)
            
            
            
            if l != self.num_layers - 1:
                cache_a = self.activationForward(Z)
            else:
                cache_a = Z
                
            layer_cache['activation'] = cache_a
            
            cache[str(l)] = layer_cache
            A = cache_a
        
        return A, cache
    
    def costFunction(self, AL, y):
        """
        :param AL: Activation of last layer, shape (num_classes, S)
        :param y: labels, shape (S)
        :param alpha: regularization parameter
        :returns cost, dAL: A scalar denoting cost and the gradient of cost
        """

        # softmax
        
        AL = self.softmax(AL) + .01
        # compute loss
        #+ np.multiply((1-Y), np.log(1-preds))
        # one hot encode true labels
        # only look at how close we are to previous labels
        true_labels = one_hot(y)
#         print("print**************\n\n prediction confidence", np.sum(preds))
#         print("\n\nna in AL?", np.sum(np.isnan(AL)), "max in AL", np.max(AL))
#         print("na in preds?", np.sum(np.isnan(preds)))
        
        
#         print("\n\ny")
#         print(y)
#         print(true_labels)
        
    
#         print("\n\npreds")
#         print(preds)
        
        y_hat = AL[y, range(y.shape[0])]
        #print("preds", y_hat)
        cost = -np.sum(np.log(y_hat))/ AL.shape[1]
        
        if self.reg_lambda > 0:
            # add regularization
            pass
        
        # gradient of cost, should be same shape as input
        # 
        #dAL = -np.divide(true_labels, AL) 
        dAL = AL - true_labels
        return cost, dAL

    def affineBackward(self, dA_prev, cache):
        """
        Backward pass for the affine layer.
        :param dA_prev: gradient from the next layer.
        :param cache: cache returned in affineForward
        :returns dA: gradient on the input to this layer
                 dW: gradient on the weights
                 db: gradient on the bias
        """
        A, W, b = cache['linear']
        #output_last_layer = cache[str(layer-1)]['activation']

     
        dW = (1/A.shape[1]) * np.dot(dA_prev,A.T)
        db = (1/A.shape[1]) * np.sum(dA_prev, axis=1, keepdims=True)
        
        dA_prev = np.dot(W.T,dA_prev)
        return dA_prev, dW, db

    def activationBackward(self, dA, cache, activation="relu"):
        """
        Interface to call backward on activation functions.
        In this case, it's just relu. 
        """
        
        #dzl = dAl*gl_p(zl)
        # only passed in the cached linear layer
        
        # zl is avation at layer l, inputted as cache
       
        zl = cache['activation']
        
        # dA is derivative last layer, first time it will be cost
        return np.multiply(dA , self.relu_derivative(zl, dA))
        
    def relu_derivative(self, cached_x, dx):
        """
        Inputs:
        dx: upstream derivative
        cached_x: input of relu

        Returns:
        dx: gradient with respect to cached_x
        """
        # this should act element-wise as well
        # if cached_x is greater than 0, then the deriv is 1.0
        # if not, then the deriv is 0
#         print("\n\nrelu deriv shape dX", dx.shape)
#         print("relu deriv, shape cached_x", cached_x.shape)
#         print("\n\n")
        
        return 1.0 * (cached_x > 0)

    def dropout_backward(self, dA, cache):

        # in backwards we need to apply that mask to the derivatives
        # so cache here contains the dropout mask you used in forward prop
        return dA

    def backPropagation(self, dAL, cache):
        """
        Run backpropagation to compute gradients on all paramters in the model
        :param dAL: gradient on the last layer of the network. Returned by the cost function.
        :param Y: labels
        :param cache: cached values during forwardprop
        :returns gradients: dW and db for each weight/bias
        """
        gradients = {}
        dA_prev = dAL
        
        for l in range(self.num_layers-1, 0, -1):
            cached_l = cache[str(l)]
            
            
            
            if l != self.num_layers - 1:
                dA_prev = self.activationBackward(dA_prev, cached_l)
    
            # affine backwards
            
            dA, dW, db = self.affineBackward(dA_prev ,cached_l)
            gradients["dW" + str(l)] = dW
            gradients["db" + str(l)] = db
#             print("shapes: dA", dA.shape)
#             print("shapes: dW", dW.shape)
#             print("shapes: db", db.shape)
#             print("\n\n")
            
            if self.drop_prob > 0:
                #call dropout_backward
                dA_prev = self.dropout_backward(dA, cache)
            else:
                dA_prev = dA
            
            
        if self.reg_lambda > 0:
            # add gradients from L2 regularization to each dW
            pass
        
        return gradients


    def updateParameters(self, gradients, alpha):
        """
        :param gradients: gradients for each weight/bias
        :param alpha: step size for gradient descent 
        """
        for l in range(1, self.num_layers):
            self.parameters["W" + str(l)] = self.parameters["W" + str(l)] - alpha * gradients["dW" + str(l)]
            self.parameters["b" + str(l)] = self.parameters["b" + str(l)] - alpha * gradients["db" + str(l)]
            
    def train(self, X, y, iters=1000, alpha=0.0001, batch_size=100, print_every=100):
        """
        :param X: input samples, each column is a sample
        :param y: labels for input samples, y.shape[0] must equal X.shape[1]
        :param iters: number of training iterations
        :param alpha: step size for gradient descent
        :param batch_size: number of samples in a minibatch
        :param print_every: no. of iterations to print debug info after
        """
        # we should get validation
        validation_X = X[:,X.shape[0]-batch_size:]
        validation_y = y[X.shape[0]-batch_size:]
        
        print("X train shape:", X_train.shape)
        print("y train shape:", y_train.shape)
        # get minibatch
#        
#         print("batch 1 x, shape:", batch_x.shape)
        #np.random.seed(0)
        # should we change alpha each step?
        

        
        
        for i in range(0, iters):
           
            start_batch = np.random.randint(X_train.shape[1] - 2*batch_size)
            #start_batch = 0
            batch_x, batch_y = self.get_batch(X, y, batch_size,start_batch)
            
            # forward prop
            last_layer, cache = self.forwardPropagation(batch_x)
            # compute loss
            cost, cost_deriv = self.costFunction(last_layer, batch_y)

            # compute gradients
            gradients = self.backPropagation(cost_deriv, cache)

            # update weights and biases based on gradient
            self.updateParameters(gradients, alpha)

            if i % print_every == 0:
                # print cost, train and validation set accuracies

                print("\n************")
                print("start batch", start_batch)
                print("COST", cost)
                print("************")
                preds = self.predict(batch_x)
                print("train accuracy = ", np.mean(preds == batch_y))
                preds_y = self.predict(validation_X)
                #print(gradients)
                print("validation set accuracy = ", np.mean(preds_y == validation_y))
                # delta gradients
                print(gradients.keys())
                #print(cost_deriv)
                for d in range(self.num_layers-1, 0, -1):
                    print("abs gradients dW"+str(d),np.mean(np.abs(gradients["dW"+str(d)])))
                
    def predict(self, X_):
        """
        Make predictions for each sample
        """
        
        forward, _ = self.forwardPropagation(X_)
        preds_ = np.argmax(forward, axis=0)
        
        return preds_

    def get_batch(self, X_, y_, batch_size, start_batch):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        # are minibatches random
        X_batch = X_[:,start_batch:(start_batch + batch_size)]
        y_batch = y_[start_batch:start_batch + batch_size]
        return X_batch, y_batch

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((num_classes, y.shape[0]))
    y_one_hot[y, range(y.shape[0])] = 1
    return y_one_hot

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0

    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)

# %%
# Load the data
data_root_path = 'cifar10-hw1/'
#X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
#X_test = get_images(data_root_path + 'test')
print('Data loading done')
# Out:
# {'airplane': 0, 'automobile': 1, 'bird': 2, 'cat': 3, 'deer': 4, 'dog': 5, 'frog': 6, 'horse': 7, 'ship': 8, 'truck': 9}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %% [markdown]
# ## Part 1
#
# #### Simple fully-connected deep neural network

# %%
layer_dimensions = [X_train.shape[0],4000, 10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=4000, alpha=.01, batch_size=1000, print_every=200)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 21676
# COST 2.3322009911
# ************
# train accuracy =  0.111
# validation set accuracy =  0.100233683859
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0429679800618
# abs gradients dW1 0.000705020234516
#
# ************
# start batch 47590
# COST 3.0479256053
# ************
# train accuracy =  0.178
# validation set accuracy =  0.165164413287
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.12090349052
# abs gradients dW1 0.00184682030378
#
# ************
# start batch 6292
# COST 3.61064140463
# ************
# train accuracy =  0.136
# validation set accuracy =  0.134618594559
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.198141457231
# abs gradients dW1 0.00200187913147
#
# ************
# start batch 14744
# COST 4.04795943331
# ************
# train accuracy =  0.153
# validation set accuracy =  0.145509931564
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.365715885033
# abs gradients dW1 0.00349193317541
#
# ************
# start batch 22185
# COST 3.92115850891
# ************
# train accuracy =  0.09
# validation set accuracy =  0.0998163912535
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.543005308233
# abs gradients dW1 0.00572896724187
#
# ************
# start batch 16810
# COST 3.91177474578
# ************
# train accuracy =  0.109
# validation set accuracy =  0.0999833082958
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.844923836455
# abs gradients dW1 0.00777573455774
#
# ************
# start batch 32208
# COST 4.18057909844
# ************
# train accuracy =  0.119
# validation set accuracy =  0.110645134368
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 1.62249670626
# abs gradients dW1 0.0147828144066
#
# ************
# start batch 29137
# COST 4.143657972
# ************
# train accuracy =  0.101
# validation set accuracy =  0.103551160073
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 2.76451939057
# abs gradients dW1 0.0167247885908
#
# ************
# start batch 44380
# COST 4.1436581343
# ************
# train accuracy =  0.096
# validation set accuracy =  0.100254548489
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 4.62937087599
# abs gradients dW1 0.0626396065374
#
# ************
# start batch 31462
# COST 4.18980933947
# ************
# train accuracy =  0.092
# validation set accuracy =  0.100150225338
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 7.3731550504
# abs gradients dW1 0.0623547377169
#
# ************
# start batch 28356
# COST 4.15750349585
# ************
# train accuracy =  0.112
# validation set accuracy =  0.10029627775
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 12.2570033331
# abs gradients dW1 0.107621452799
#
# ************
# start batch 18806
# COST 3.99597427777
# ************
# train accuracy =  0.089
# validation set accuracy =  0.10031714238
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 18.5014586567
# abs gradients dW1 0.030459800144
#
# ************
# start batch 43941
# COST 4.17134885741
# ************
# train accuracy =  0.161
# validation set accuracy =  0.15569187114
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 34.7524593106
# abs gradients dW1 0.255447398552
#
# ************
# start batch 6039
# COST 3.91290210846
# ************
# train accuracy =  0.134
# validation set accuracy =  0.143799031881
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 52.5570319613
# abs gradients dW1 0.309641394655
#
# ************
# start batch 32165
# COST 4.10212204965
# ************
# train accuracy =  0.11
# validation set accuracy =  0.103050408947
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 97.5989204505
# abs gradients dW1 1.41333858806
#
# ************
# start batch 47422
# COST 4.19442445999
# ************
# train accuracy =  0.116
# validation set accuracy =  0.100338007011
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 166.491253064
# abs gradients dW1 1.76272750106
#
# ************
# start batch 39331
# COST 3.96366843415
# ************
# train accuracy =  0.131
# validation set accuracy =  0.152979469204
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 238.527382255
# abs gradients dW1 2.13314747281
#
# ************
# start batch 46135
# COST 4.14827325482
# ************
# train accuracy =  0.094
# validation set accuracy =  0.100338007011
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 448.85012279
# abs gradients dW1 5.11143028153
#
# ************
# start batch 2486
# COST 4.12519765224
# ************
# train accuracy =  0.159
# validation set accuracy =  0.155065932232
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 690.131864404
# abs gradients dW1 2.8568551998
#
# ************
# start batch 17821
# COST 4.07904644707
# ************
# train accuracy =  0.109
# validation set accuracy =  0.0996912034719
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 1186.33169571
# abs gradients dW1 18.4415015058

# %%
layer_dimensions = [X_train.shape[0],200, 300, 400, 10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=4000, alpha=.001, batch_size=1000, print_every=200)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2', 'W3', 'b3', 'W4', 'b4'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 10751
# COST 2.23159467912
# ************
# train accuracy =  0.094
# validation set accuracy =  0.0998998497747
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0225828894205
# abs gradients dW3 0.000669922158785
# abs gradients dW2 0.000143517691722
# abs gradients dW1 1.09204233045e-05
#
# ************
# start batch 5211
# COST 2.20733543793
# ************
# train accuracy =  0.093
# validation set accuracy =  0.100108496077
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0117060112595
# abs gradients dW3 0.000389878440369
# abs gradients dW2 7.56449213882e-05
# abs gradients dW1 7.45659186462e-06
#
# ************
# start batch 19650
# COST 2.20709967273
# ************
# train accuracy =  0.103
# validation set accuracy =  0.100400600901
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0108638915471
# abs gradients dW3 0.000484117916141
# abs gradients dW2 9.93721769652e-05
# abs gradients dW1 9.90628414615e-06
#
# ************
# start batch 21374
# COST 2.20699272834
# ************
# train accuracy =  0.105
# validation set accuracy =  0.100338007011
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0120518735954
# abs gradients dW3 0.000656447027565
# abs gradients dW2 0.000139794585106
# abs gradients dW1 1.33731124541e-05
#
# ************
# start batch 44830
# COST 2.20817580777
# ************
# train accuracy =  0.099
# validation set accuracy =  0.100025037556
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0114069653843
# abs gradients dW3 0.000836116292515
# abs gradients dW2 0.000200883220507
# abs gradients dW1 1.87740709558e-05
#
# ************
# start batch 11668
# COST 2.20775979978
# ************
# train accuracy =  0.099
# validation set accuracy =  0.0997955266233
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0127249338299
# abs gradients dW3 0.00107112374798
# abs gradients dW2 0.000317715880198
# abs gradients dW1 2.67938274504e-05
#
# ************
# start batch 29332
# COST 2.20810399534
# ************
# train accuracy =  0.114
# validation set accuracy =  0.0996912034719
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0159420657568
# abs gradients dW3 0.00133758718799
# abs gradients dW2 0.000513303030577
# abs gradients dW1 4.32780079614e-05
#
# ************
# start batch 4059
# COST 2.20823700676
# ************
# train accuracy =  0.097
# validation set accuracy =  0.0999833082958
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0191337390438
# abs gradients dW3 0.00164897072557
# abs gradients dW2 0.00082305290552
# abs gradients dW1 7.39950420648e-05
#
# ************
# start batch 22507
# COST 2.20692240824
# ************
# train accuracy =  0.105
# validation set accuracy =  0.0997955266233
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.01496274587
# abs gradients dW3 0.00204899444312
# abs gradients dW2 0.00130185955091
# abs gradients dW1 0.000140707311677
#
# ************
# start batch 11320
# COST 2.20690980073
# ************
# train accuracy =  0.115
# validation set accuracy =  0.100233683859
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0195718154761
# abs gradients dW3 0.00260502320012
# abs gradients dW2 0.00208046943948
# abs gradients dW1 0.00029295846944
#
# ************
# start batch 1611
# COST 2.20664314079
# ************
# train accuracy =  0.112
# validation set accuracy =  0.0999833082958
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0219203779739
# abs gradients dW3 0.00350821892185
# abs gradients dW2 0.00354114829238
# abs gradients dW1 0.000669268864495
#
# ************
# start batch 43934
# COST 2.2098701355
# ************
# train accuracy =  0.157
# validation set accuracy =  0.137414455016
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0387260446701
# abs gradients dW3 0.00559817737448
# abs gradients dW2 0.00710410075458
# abs gradients dW1 0.00175852162177
#
# ************
# start batch 7791
# COST 2.41658077732
# ************
# train accuracy =  0.11
# validation set accuracy =  0.100338007011
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.40052488964
# abs gradients dW3 0.0147501253534
# abs gradients dW2 0.0220363002136
# abs gradients dW1 0.00655327360319
#
# ************
# start batch 16366
# COST 3.85364974662
# ************
# train accuracy =  0.114
# validation set accuracy =  0.0998163912535
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 2.25640116427
# abs gradients dW3 0.0389005025734
# abs gradients dW2 0.00953764768378
# abs gradients dW1 0.00303158309253
#
# ************
# start batch 27539
# COST 4.13423766042
# ************
# train accuracy =  0.1
# validation set accuracy =  0.0999833082958
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 3.60570535241
# abs gradients dW3 0.0512105831408
# abs gradients dW2 0.0120559697233
# abs gradients dW1 0.00398848759462
#
# ************
# start batch 4481
# COST 4.13442789327
# ************
# train accuracy =  0.088
# validation set accuracy =  0.0996912034719
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 5.67419690628
# abs gradients dW3 0.0562008627096
# abs gradients dW2 0.0255345034191
# abs gradients dW1 0.00749994619313
#
# ************
# start batch 20063
# COST 4.22673030361
# ************
# train accuracy =  0.108
# validation set accuracy =  0.100400600901
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 9.51559025784
# abs gradients dW3 0.0398216438513
# abs gradients dW2 0.0219936469654
# abs gradients dW1 0.00682837209157
#
# ************
# start batch 46455
# COST 4.09289180862
# ************
# train accuracy =  0.103
# validation set accuracy =  0.0998163912535
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 14.2905187457
# abs gradients dW3 0.0711828508403
# abs gradients dW2 0.107864845282
# abs gradients dW1 0.0348461344997
#
# ************
# start batch 9579
# COST 4.18057909844
# ************
# train accuracy =  0.11
# validation set accuracy =  0.0997955266233
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 8.34691862594
# abs gradients dW3 0.163403621617
# abs gradients dW2 0.242393671732
# abs gradients dW1 0.0776380060079
#
# ************
# start batch 1470
# COST 3.58883326498
# ************
# train accuracy =  0.113
# validation set accuracy =  0.0997329327324
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 1.17553428743
# abs gradients dW3 0.101225929709
# abs gradients dW2 0.138087759421
# abs gradients dW1 0.0460201850963

# %%
layer_dimensions = [X_train.shape[0],15,32,12, 10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=4000, alpha=.001, batch_size=500, print_every=200)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2', 'W3', 'b3', 'W4', 'b4'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 46716
# COST 2.2077076885
# ************
# train accuracy =  0.09
# validation set accuracy =  0.100278316606
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0131072078717
# abs gradients dW3 0.000535223858764
# abs gradients dW2 1.6983786266e-05
# abs gradients dW1 4.70142490806e-07
#
# ************
# start batch 36106
# COST 2.20737135239
# ************
# train accuracy =  0.096
# validation set accuracy =  0.100278316606
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0113555108923
# abs gradients dW3 0.000617095155894
# abs gradients dW2 1.83635045914e-05
# abs gradients dW1 6.08372786663e-07
#
# ************
# start batch 26687
# COST 2.20763397857
# ************
# train accuracy =  0.098
# validation set accuracy =  0.0997933710045
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0118262434213
# abs gradients dW3 0.00045409241231
# abs gradients dW2 1.36668348078e-05
# abs gradients dW1 4.40451027524e-07
#
# ************
# start batch 45399
# COST 2.20696220207
# ************
# train accuracy =  0.112
# validation set accuracy =  0.100278316606
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0100129862084
# abs gradients dW3 0.000552911524643
# abs gradients dW2 2.34555500708e-05
# abs gradients dW1 7.00226744393e-07
#
# ************
# start batch 18424
# COST 2.20650323316
# ************
# train accuracy =  0.108
# validation set accuracy =  0.0997933710045
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0172324869788
# abs gradients dW3 0.000816839699299
# abs gradients dW2 3.38426267608e-05
# abs gradients dW1 7.47471826457e-07
#
# ************
# start batch 10575
# COST 2.20687705921
# ************
# train accuracy =  0.106
# validation set accuracy =  0.0997933710045
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0102782534733
# abs gradients dW3 0.000914637042662
# abs gradients dW2 3.28740269317e-05
# abs gradients dW1 8.07412638857e-07
#
# ************
# start batch 22157
# COST 2.20677885124
# ************
# train accuracy =  0.136
# validation set accuracy =  0.0997933710045
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0166923451952
# abs gradients dW3 0.00112144026669
# abs gradients dW2 3.88570013264e-05
# abs gradients dW1 7.88566014839e-07
#
# ************
# start batch 47039
# COST 2.20743843531
# ************
# train accuracy =  0.092
# validation set accuracy =  0.0997933710045
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0139918986893
# abs gradients dW3 0.0012719195984
# abs gradients dW2 5.26831518794e-05
# abs gradients dW1 1.20923501758e-06
#
# ************
# start batch 38393
# COST 2.20709126565
# ************
# train accuracy =  0.098
# validation set accuracy =  0.0981909420595
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0148436809746
# abs gradients dW3 0.00149710007663
# abs gradients dW2 5.62546953806e-05
# abs gradients dW1 1.37474881442e-06
#
# ************
# start batch 7511
# COST 2.20721354268
# ************
# train accuracy =  0.096
# validation set accuracy =  0.100215062832
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0107980276064
# abs gradients dW3 0.00168629091663
# abs gradients dW2 6.23868221836e-05
# abs gradients dW1 1.56509783095e-06
#
# ************
# start batch 17323
# COST 2.20716512129
# ************
# train accuracy =  0.098
# validation set accuracy =  0.100172893649
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0136421174623
# abs gradients dW3 0.00190436591063
# abs gradients dW2 7.04909151372e-05
# abs gradients dW1 1.78943938019e-06
#
# ************
# start batch 9960
# COST 2.20717052688
# ************
# train accuracy =  0.128
# validation set accuracy =  0.100151809058
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0157116161709
# abs gradients dW3 0.00209603390399
# abs gradients dW2 8.4635109526e-05
# abs gradients dW1 2.03273683569e-06
#
# ************
# start batch 27283
# COST 2.20737984621
# ************
# train accuracy =  0.11
# validation set accuracy =  0.0997933710045
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0134697191401
# abs gradients dW3 0.00232129020453
# abs gradients dW2 9.40762123366e-05
# abs gradients dW1 2.09189425999e-06
#
# ************
# start batch 44608
# COST 2.20725125744
# ************
# train accuracy =  0.092
# validation set accuracy =  0.0997933710045
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0138332894075
# abs gradients dW3 0.00252509423501
# abs gradients dW2 0.000115396404965
# abs gradients dW1 2.58275360532e-06
#
# ************
# start batch 37965
# COST 2.20703137549
# ************
# train accuracy =  0.124
# validation set accuracy =  0.0997933710045
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0170913622212
# abs gradients dW3 0.0027597501607
# abs gradients dW2 0.000142384375521
# abs gradients dW1 2.88194009179e-06
#
# ************
# start batch 33537
# COST 2.20744624823
# ************
# train accuracy =  0.088
# validation set accuracy =  0.0997933710045
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0149043919665
# abs gradients dW3 0.00294819996377
# abs gradients dW2 0.000168564428875
# abs gradients dW1 3.56931444427e-06
#
# ************
# start batch 48572
# COST 2.20751994691
# ************
# train accuracy =  0.09
# validation set accuracy =  0.100531331703
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0138774246916
# abs gradients dW3 0.00317221616659
# abs gradients dW2 0.000200535256222
# abs gradients dW1 4.11918739831e-06
#
# ************
# start batch 12774
# COST 2.20729757703
# ************
# train accuracy =  0.11
# validation set accuracy =  0.0997722864131
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.015511698343
# abs gradients dW3 0.0034302072677
# abs gradients dW2 0.000244537821227
# abs gradients dW1 4.72639402491e-06
#
# ************
# start batch 17634
# COST 2.20733136528
# ************
# train accuracy =  0.102
# validation set accuracy =  0.0997722864131
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0172125119646
# abs gradients dW3 0.00365480543368
# abs gradients dW2 0.00029384495767
# abs gradients dW1 5.55398654712e-06
#
# ************
# start batch 23611
# COST 2.20737688387
# ************
# train accuracy =  0.102
# validation set accuracy =  0.0997933710045
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.020055134695
# abs gradients dW3 0.00389826754265
# abs gradients dW2 0.000351576387212
# abs gradients dW1 6.45813374408e-06

# %%
layer_dimensions = [X_train.shape[0],30, 6, 10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=4000, alpha=.0001, batch_size=7000, print_every=200)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2', 'W3', 'b3'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 14114
# COST 2.20715169581
# ************
# train accuracy =  0.102
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945521325091
# abs gradients dW2 0.000234454324104
# abs gradients dW1 4.89209717514e-06
#
# ************
# start batch 18199
# COST 2.20716218188
# ************
# train accuracy =  0.106285714286
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945476490005
# abs gradients dW2 0.000346300448191
# abs gradients dW1 5.27473099835e-06
#
# ************
# start batch 31345
# COST 2.20734950085
# ************
# train accuracy =  0.099
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945299065597
# abs gradients dW2 0.000305508758258
# abs gradients dW1 5.43836222685e-06
#
# ************
# start batch 25641
# COST 2.20743657961
# ************
# train accuracy =  0.0978571428571
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0094535773321
# abs gradients dW2 0.000245434857961
# abs gradients dW1 4.93721111516e-06
#
# ************
# start batch 78
# COST 2.20743454104
# ************
# train accuracy =  0.0978571428571
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945268004755
# abs gradients dW2 0.000276326563617
# abs gradients dW1 5.20318866703e-06
#
# ************
# start batch 28055
# COST 2.20733122159
# ************
# train accuracy =  0.102571428571
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945310428383
# abs gradients dW2 0.000275403408925
# abs gradients dW1 4.69367870919e-06
#
# ************
# start batch 31746
# COST 2.20729746644
# ************
# train accuracy =  0.0997142857143
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945294616112
# abs gradients dW2 0.000326864825477
# abs gradients dW1 4.95058506486e-06
#
# ************
# start batch 4083
# COST 2.20723940038
# ************
# train accuracy =  0.1
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945409585888
# abs gradients dW2 0.000373008721399
# abs gradients dW1 4.7865810806e-06
#
# ************
# start batch 15920
# COST 2.20722334488
# ************
# train accuracy =  0.1
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945473355854
# abs gradients dW2 0.000312803427621
# abs gradients dW1 4.48485242418e-06
#
# ************
# start batch 1293
# COST 2.20726854318
# ************
# train accuracy =  0.101142857143
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945498832841
# abs gradients dW2 0.000295757366857
# abs gradients dW1 4.71257714306e-06
#
# ************
# start batch 25318
# COST 2.20739598556
# ************
# train accuracy =  0.0972857142857
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945635311078
# abs gradients dW2 0.000275338913724
# abs gradients dW1 4.2072215342e-06
#
# ************
# start batch 23569
# COST 2.20738384211
# ************
# train accuracy =  0.100571428571
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945774696666
# abs gradients dW2 0.000286063816994
# abs gradients dW1 4.13695760561e-06
#
# ************
# start batch 13059
# COST 2.20719153132
# ************
# train accuracy =  0.102714285714
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945882594336
# abs gradients dW2 0.000292001257175
# abs gradients dW1 4.2847468962e-06
#
# ************
# start batch 24077
# COST 2.20731352949
# ************
# train accuracy =  0.100285714286
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00945984558953
# abs gradients dW2 0.000318908027313
# abs gradients dW1 4.23562678088e-06
#
# ************
# start batch 1355
# COST 2.20726059738
# ************
# train accuracy =  0.100714285714
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00946032435944
# abs gradients dW2 0.000339605381908
# abs gradients dW1 4.82545633428e-06
#
# ************
# start batch 22840
# COST 2.20742787382
# ************
# train accuracy =  0.100857142857
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00946259816855
# abs gradients dW2 0.00030950333809
# abs gradients dW1 4.28984001923e-06
#
# ************
# start batch 487
# COST 2.20733949417
# ************
# train accuracy =  0.0994285714286
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00946310527298
# abs gradients dW2 0.000344186737191
# abs gradients dW1 4.80520788574e-06
#
# ************
# start batch 5214
# COST 2.20734852337
# ************
# train accuracy =  0.0984285714286
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0094657734133
# abs gradients dW2 0.000363141158645
# abs gradients dW1 4.58268253967e-06
#
# ************
# start batch 31350
# COST 2.20731578624
# ************
# train accuracy =  0.0992857142857
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00946690657763
# abs gradients dW2 0.000387629096026
# abs gradients dW1 5.0936128555e-06
#
# ************
# start batch 27106
# COST 2.20736156521
# ************
# train accuracy =  0.101142857143
# validation set accuracy =  0.0898676171079
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00946933274465
# abs gradients dW2 0.000350975352305
# abs gradients dW1 4.80646109053e-06

# %%
y_predicted = NN.predict(X_test)
save_predictions('ans1-uni', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans1-uni.npy')
print(loaded_y.shape)
loaded_y[:10]

# %% [markdown]
# ## Part 2: Regularizing the neural network
# #### Add dropout and L2 regularization

# %%
NN2 = NeuralNetwork(layer_dimensions, drop_prob=0, reg_lambda=0)
NN2.train(X_train, y_train, iters=100, alpha=0.05, batch_size=1000, print_every=1)

# %%
y_predicted2 = NN2.predict(X)
save_predictions(y_predicted, 'ans2-uni')

# %%
test = np.random.randint(10, size=(6))
test
# Out:
# array([5, 0, 3, 3, 7, 9])

# %%
T = one_hot(test)
T

# %%
np.random.randint(10)
# Out:
# 3
