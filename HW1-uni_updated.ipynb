# %% [markdown]
# # COMS 4995_002 Deep Learning Assignment 1
# Due on Monday, Oct 9, 11:59pm
#
# This assignment can be done in groups of at most 3 students. Everyone must submit on Courseworks individually.

# %% [markdown]
# Write down the UNIs of your group (if applicable)
#
# Member 1: Name, UNI
#
# Member 2: Name, UNI
#
# Member 3: Name, UNI

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
# you shouldn't need to make any more imports

# %%
class NeuralNetwork(object):
    """
    Abstraction of neural network.
    Stores parameters, activations, cached values. 
    Provides necessary functions for training and prediction. 
    """
    def __init__(self, layer_dimensions, drop_prob=0.0, reg_lambda=0.0):
        """
        Initializes the weights and biases for each layer
        :param layer_dimensions: (list) number of nodes in each layer
        :param drop_prob: drop probability for dropout layers. Only required in part 2 of the assignment
        :param reg_lambda: regularization parameter. Only required in part 2 of the assignment
        """
        
        eps = .01
        self.parameters = {'layer_dimensions':layer_dimensions, 'drop_prob':drop_prob, 'reg_lambda':reg_lambda} 
        self.num_layers = len(layer_dimensions)
        self.drop_prob = drop_prob
        self.reg_lambda = reg_lambda
        
        # init parameters
        for l in range(1, self.num_layers):
            self.parameters['W' + str(l)] = np.random.normal(size=(layer_dimensions[l], layer_dimensions[l-1]))  * 1/np.sqrt(layer_dimensions[l-1])
            self.parameters['b' + str(l)]= np.ones((layer_dimensions[l], 1))
    
        # print all params:
        print(self.parameters.keys())

        
#     def gradientCheck(self, theta, x):
#         eps = 1e-7
#         J_pos = J(theta + eps, x)
#         J_neg = J(theta - eps, x)
#         numerical_deriv = (J_pos - J-neg)/(2*eps)
#         analytic_deriv = JDeriv(theta, x)
#         error = norm(numerical_deriv-analyic_deriv)/norm()
#         return error
        
    def affineForward(self, A_, W_, b_):
        """
        Forward pass for the affine layer.
        :param A: input matrix, shape (L, S), where L is the number of hidden units in the previous layer and S is
        the number of samples
        :returns: the affine product WA + b, along with the cache required for the backward pass
        """
#         print("forward, shape W", W_.shape)
#         print("forward, shape A", A_.shape)
#         print("forward, shape b", b_.shape)
        return np.dot(W_, A_) + b_, [A_, W_, b_]
        

    def activationForward(self, A_, activation="relu"):
        """
        Common interface to access all activation functions.
        :param A: input to the activation function
        :param prob: activation funciton to apply to A. Just "relu" for this assignment.
        :returns: activation(A)
        """ 
        
        if activation == "relu":
            return self.relu(A_)
        if activation == "softmax":
            return self.softmax(A_)
        
        return A_

    def softmax(self, x):
        # softmax
        
        e_x = np.exp(x - np.max(x,axis=0))
        return e_x / e_x.sum( axis=0)
    
    def relu(self, X):
        return np.maximum(0,X)
            
    def dropout(self, A, prob):
        """
        :param A: 
        :param prob: drop prob
        :returns: tuple (A, M) 
            WHERE
            A is matrix after applying dropout
            M is dropout mask, used in the backward pass
        """
        
        # make a mask, binary mask
        # where that mask is 0, drop those activation units
        # where its one, scale them up by 1/(1-p)
        # in forward we need to apply this mask
        
        M = np.random.binomial([np.ones(A.shape)],1-prob)[0] * (1.0/(1-prob))
        A = np.multiply(A, M)
        
        return A, M

    def forwardPropagation(self, X, training=False):
        """
        Runs an input X through the neural network to compute activations
        for all layers. Returns the output computed at the last layer along
        with the cache required for backpropagation.
        :returns: (tuple) AL, cache
            WHERE 
            AL is activation of last layer
            cache is cached values for each layer that
                     are needed in further steps
        """
        cache = {}
        A = X
        
        for l in range(1, self.num_layers):

            
            layer_cache = {}
            layer_cache["linear"] = [A,  self.parameters["W" + str(l)], self.parameters["b" + str(l)]]
            Z, cache_l = self.affineForward(A, self.parameters["W" + str(l)], self.parameters["b" + str(l)])
#             print("forward, layer", l)         
# #             print("forward shapes: Z, ", Z.shape)
            
            
            
            if l != self.num_layers - 1:
                cache_a = self.activationForward(Z)
                if self.drop_prob > 0:
                    cache_a, dropout_mask = self.dropout(cache_a, self.drop_prob)
                    layer_cache['dropout'] = M
            else:
                cache_a = Z
            
            
            
            layer_cache['activation'] = cache_a
            cache[str(l)] = layer_cache
            
            A = cache_a
        
        return A, cache
    
    def costFunction(self, AL, y):
        """
        :param AL: Activation of last layer, shape (num_classes, S)
        :param y: labels, shape (S)
        :param alpha: regularization parameter
        :returns cost, dAL: A scalar denoting cost and the gradient of cost
        """

        # softmax
        
        AL = self.softmax(AL)
        # compute loss
        #+ np.multiply((1-Y), np.log(1-preds))
        # one hot encode true labels
        # only look at how close we are to previous labels
        true_labels = one_hot(y)

        
        y_hat = AL[y, range(y.shape[0])]
        #print("preds", y_hat)
        cost = -np.sum(np.log(y_hat))/ AL.shape[1]
        
        if self.reg_lambda > 0:
            # add regularization
            pass
        
        # gradient of cost, should be same shape as input
        # 
        #dAL = -np.divide(true_labels, AL) 
        dAL = AL - true_labels
        return cost, dAL

    def affineBackward(self, dA_prev, cache):
        """
        Backward pass for the affine layer.
        :param dA_prev: gradient from the next layer.
        :param cache: cache returned in affineForward
        :returns dA: gradient on the input to this layer
                 dW: gradient on the weights
                 db: gradient on the bias
        """
        A, W, b = cache['linear']
        #output_last_layer = cache[str(layer-1)]['activation']

     
        dW = (1/A.shape[1]) * np.dot(dA_prev,A.T)
        db = (1/A.shape[1]) * np.sum(dA_prev, axis=1, keepdims=True)
        
        dA_prev = np.dot(W.T,dA_prev)
        return dA_prev, dW, db

    def activationBackward(self, dA, cache, activation="relu"):
        """
        Interface to call backward on activation functions.
        In this case, it's just relu. 
        """
        
        #dzl = dAl*gl_p(zl)
        # only passed in the cached linear layer
        
        # zl is avation at layer l, inputted as cache
       
        zl = cache['activation']
        
        # dA is derivative last layer, first time it will be cost
        return np.multiply(dA , self.relu_derivative(zl, dA))
        
    def relu_derivative(self, cached_x, dx):
        """
        Inputs:
        dx: upstream derivative
        cached_x: input of relu

        Returns:
        dx: gradient with respect to cached_x
        """
        # this should act element-wise as well
        # if cached_x is greater than 0, then the deriv is 1.0
        # if not, then the deriv is 0
#         print("\n\nrelu deriv shape dX", dx.shape)
#         print("relu deriv, shape cached_x", cached_x.shape)
#         print("\n\n")
        
        return 1.0 * (cached_x > 0)

    def dropout_backward(self, dA, cache):

        # in backwards we need to apply that mask to the derivatives
        # so cache here contains the dropout mask you used in forward prop
        mask = cache['dropout']
        
        return np.multiply(dA, mask)

    def backPropagation(self, dAL, cache):
        """
        Run backpropagation to compute gradients on all paramters in the model
        :param dAL: gradient on the last layer of the network. Returned by the cost function.
        :param Y: labels
        :param cache: cached values during forwardprop
        :returns gradients: dW and db for each weight/bias
        """
        gradients = {}
        dA_prev = dAL
        
        for l in range(self.num_layers-1, 0, -1):
            cached_l = cache[str(l)]

            if l != self.num_layers - 1:
                dA_prev = self.activationBackward(dA_prev, cached_l)
    
            # affine backwards
            
            dA, dW, db = self.affineBackward(dA_prev ,cached_l)
            gradients["dW" + str(l)] = dW
            gradients["db" + str(l)] = db
#             print("shapes: dA", dA.shape)
#             print("shapes: dW", dW.shape)
#             print("shapes: db", db.shape)
#             print("\n\n")
            
            if self.num_layers != -1 and self.drop_prob > 0:
                #call dropout_backward
                dA_prev = self.dropout_backward(dA, cache)
            else:
                dA_prev = dA
            
            
        if self.reg_lambda > 0:
            # add gradients from L2 regularization to each dW
            pass
        
        return gradients


    def updateParameters(self, gradients, alpha):
        """
        :param gradients: gradients for each weight/bias
        :param alpha: step size for gradient descent 
        """
        for l in range(1, self.num_layers):
            self.parameters["W" + str(l)] = self.parameters["W" + str(l)] - alpha * gradients["dW" + str(l)]
            self.parameters["b" + str(l)] = self.parameters["b" + str(l)] - alpha * gradients["db" + str(l)]
            
    def train(self, X, y, iters=1000, alpha=0.0001, batch_size=100, print_every=100):
        """
        :param X: input samples, each column is a sample
        :param y: labels for input samples, y.shape[0] must equal X.shape[1]
        :param iters: number of training iterations
        :param alpha: step size for gradient descent
        :param batch_size: number of samples in a minibatch
        :param print_every: no. of iterations to print debug info after
        """
        # we should get validation
        validation_X = X[:,X.shape[0]-batch_size:]
        validation_y = y[X.shape[0]-batch_size:]
        
        print("X train shape:", X_train.shape)
        print("y train shape:", y_train.shape)
        # get minibatch
#        
#         print("batch 1 x, shape:", batch_x.shape)
        #np.random.seed(0)
        # should we change alpha each step?
        

        
        
        for i in range(0, iters):
           
            start_batch = np.random.randint(X_train.shape[1] - 2*batch_size)
            #start_batch = 0
            batch_x, batch_y = self.get_batch(X, y, batch_size,start_batch)
            
            # forward prop
            last_layer, cache = self.forwardPropagation(batch_x, training=True)
            # compute loss
            cost, cost_deriv = self.costFunction(last_layer, batch_y)

            # compute gradients
            gradients = self.backPropagation(cost_deriv, cache)

            # update weights and biases based on gradient
            self.updateParameters(gradients, alpha)

            if i % print_every == 0:
                # print cost, train and validation set accuracies
                if i % 100 == 0 and i != 0:
                    alpha = 1/(100*np.mean(np.abs(gradients["dW"+str(self.num_layers-1)])))
                print("\n************")
                print("start batch", start_batch, "iter", i)
                print("COST", cost)
                print("alpha", alpha)
                print("************")
                #preds = self.predict(batch_x)
                preds = np.argmax(batch_x, axis=0)
                print("train accuracy = ", np.mean(preds == batch_y))
                preds_y = self.predict(validation_X)
                #print(gradients)
                print("validation set accuracy = ", np.mean(preds_y == validation_y))
                # delta gradients
                print(gradients.keys())
                #print(cost_deriv)
                for d in range(self.num_layers-1, 0, -1):
                    print("abs gradients dW"+str(d),np.mean(np.abs(gradients["dW"+str(d)])))
                
    def predict(self, X_):
        """
        Make predictions for each sample
        """
        
        forward, _ = self.forwardPropagation(X_, training=False)
        preds_ = np.argmax(forward, axis=0)
        
        return preds_

    def get_batch(self, X_, y_, batch_size, start_batch):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        # are minibatches random
        #get random set
        ix = np.random.choice(X_.shape[1], batch_size, replace=True)
        X_batch = X_[:,ix]
        y_batch = y_[ix]
        return X_batch, y_batch

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((num_classes, y.shape[0]))
    y_one_hot[y, range(y.shape[0])] = 1
    return y_one_hot

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0

    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)

# %%
# Load the data
data_root_path = 'cifar10-hw1/'
#X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
#X_test = get_images(data_root_path + 'test')
print('Data loading done')
# Out:
# {'airplane': 0, 'automobile': 1, 'bird': 2, 'cat': 3, 'deer': 4, 'dog': 5, 'frog': 6, 'horse': 7, 'ship': 8, 'truck': 9}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %% [markdown]
# ## Part 1
#
# #### Simple fully-connected deep neural network

# %%
# layer_dimensions = [X_train.shape[0],4000, 2000, 10]  # including the input and output layers
# NN = NeuralNetwork(layer_dimensions)
# NN.train(X_train, y_train, iters=4000, alpha=.0001, batch_size=500, print_every=10)

# %%
layer_dimensions = [X_train.shape[0],7000,  10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=4000, alpha=.005, batch_size=1000, print_every=20)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 8649 iter 0
# COST 2.89546547733
# alpha 0.005
# ************
# train accuracy =  0.002
# validation set accuracy =  0.0999624436655
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0851687406811
# abs gradients dW1 0.00183095977877
#
# ************
# start batch 47066 iter 20
# COST 7.12728969871
# alpha 0.005
# ************
# train accuracy =  0.007
# validation set accuracy =  0.157340176932
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.141639975455
# abs gradients dW1 0.00318909994974
#
# ************
# start batch 29086 iter 40
# COST 5.95349026046
# alpha 0.005
# ************
# train accuracy =  0.01
# validation set accuracy =  0.160782840928
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.124127017116
# abs gradients dW1 0.00245996941445
#
# ************
# start batch 251 iter 60
# COST 4.85751859739
# alpha 0.005
# ************
# train accuracy =  0.013
# validation set accuracy =  0.179477549658
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0791704856068
# abs gradients dW1 0.00134809438929
#
# ************
# start batch 16003 iter 80
# COST 2.88577338997
# alpha 0.005
# ************
# train accuracy =  0.003
# validation set accuracy =  0.18262810883
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0709309476407
# abs gradients dW1 0.00131358585693
#
# ************
# start batch 4094 iter 100
# COST 3.1713273291
# alpha 0.005
# ************
# train accuracy =  0.004
# validation set accuracy =  0.209460023368
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0931884235363
# abs gradients dW1 0.00158168252094
#
# ************
# start batch 34572 iter 120
# COST 3.06788264723
# alpha 0.005
# ************
# train accuracy =  0.012
# validation set accuracy =  0.253317476214
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0731672087724
# abs gradients dW1 0.0014958815382
#
# ************
# start batch 25707 iter 140
# COST 2.99935676287
# alpha 0.005
# ************
# train accuracy =  0.011
# validation set accuracy =  0.191474712068
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0715781897518
# abs gradients dW1 0.00139373405728
#
# ************
# start batch 34978 iter 160
# COST 2.68110670498
# alpha 0.005
# ************
# train accuracy =  0.012
# validation set accuracy =  0.213841595727
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0601708841661
# abs gradients dW1 0.00111554384509
#
# ************
# start batch 37244 iter 180
# COST 2.47964411775
# alpha 0.005
# ************
# train accuracy =  0.009
# validation set accuracy =  0.259931564013
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0580152548013
# abs gradients dW1 0.00130992077638
#
# ************
# start batch 7794 iter 200
# COST 2.40342129622
# alpha 0.005
# ************
# train accuracy =  0.004
# validation set accuracy =  0.257302620598
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0438729260924
# abs gradients dW1 0.000872015749929
#
# ************
# start batch 36795 iter 220
# COST 2.10280685863
# alpha 0.005
# ************
# train accuracy =  0.006
# validation set accuracy =  0.263645468202
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.042947405931
# abs gradients dW1 0.000827183210051
#
# ************
# start batch 544 iter 240
# COST 2.3678261471
# alpha 0.005
# ************
# train accuracy =  0.01
# validation set accuracy =  0.222375229511
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0467563194945
# abs gradients dW1 0.00086799197529
#
# ************
# start batch 23487 iter 260
# COST 2.42463552377
# alpha 0.005
# ************
# train accuracy =  0.013
# validation set accuracy =  0.260077616425
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0475108345934
# abs gradients dW1 0.000916272095238
#
# ************
# start batch 31516 iter 280
# COST 2.34615980961
# alpha 0.005
# ************
# train accuracy =  0.008
# validation set accuracy =  0.245326322818
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0460663739731
# abs gradients dW1 0.000859370315266
#
# ************
# start batch 31694 iter 300
# COST 2.01620816319
# alpha 0.0025
# ************
# train accuracy =  0.006
# validation set accuracy =  0.338653814054
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0308563930923
# abs gradients dW1 0.000600171928863
#
# ************
# start batch 24400 iter 320
# COST 1.81603892066
# alpha 0.0025
# ************
# train accuracy =  0.012
# validation set accuracy =  0.360478217326
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00992620660629
# abs gradients dW1 0.000248081239348
#
# ************
# start batch 5084 iter 340
# COST 1.85928659902
# alpha 0.0025
# ************
# train accuracy =  0.007
# validation set accuracy =  0.367467868469
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00815533619496
# abs gradients dW1 0.000171145767599
#
# ************
# start batch 5833 iter 360
# COST 1.85662939614
# alpha 0.0025
# ************
# train accuracy =  0.009
# validation set accuracy =  0.366341178434
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00763292626963
# abs gradients dW1 0.000195042657133
#
# ************
# start batch 33403 iter 380
# COST 1.80583299814
# alpha 0.0025
# ************
# train accuracy =  0.007
# validation set accuracy =  0.37575112669
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00555127891949
# abs gradients dW1 0.000123004928964
#
# ************
# start batch 24704 iter 400
# COST 1.8068466952
# alpha 0.0025
# ************
# train accuracy =  0.005
# validation set accuracy =  0.365318811551
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.010668624586
# abs gradients dW1 0.000199623239371
#
# ************
# start batch 10059 iter 420
# COST 1.85847785285
# alpha 0.0025
# ************
# train accuracy =  0.008
# validation set accuracy =  0.36750959773
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00881206676786
# abs gradients dW1 0.00016817346267
#
# ************
# start batch 28004 iter 440
# COST 1.81162414038
# alpha 0.0025
# ************
# train accuracy =  0.014
# validation set accuracy =  0.370430645969
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00925551409651
# abs gradients dW1 0.000189854421274
#
# ************
# start batch 35936 iter 460
# COST 1.81299311004
# alpha 0.0025
# ************
# train accuracy =  0.007
# validation set accuracy =  0.372913536972
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00941943345337
# abs gradients dW1 0.000204159445934
#
# ************
# start batch 9026 iter 480
# COST 1.84669314642
# alpha 0.0025
# ************
# train accuracy =  0.011
# validation set accuracy =  0.378505257887
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00832447226577
# abs gradients dW1 0.00020309772599
#
# ************
# start batch 44358 iter 500
# COST 1.8442982991
# alpha 0.0025
# ************
# train accuracy =  0.008
# validation set accuracy =  0.376606576531
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0092587813743
# abs gradients dW1 0.000184561088545
#
# ************
# start batch 1705 iter 520
# COST 1.8291244405
# alpha 0.0025
# ************
# train accuracy =  0.007
# validation set accuracy =  0.37648138875
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0111653063221
# abs gradients dW1 0.0002568129223
#
# ************
# start batch 4886 iter 540
# COST 1.80175988961
# alpha 0.0025
# ************
# train accuracy =  0.009
# validation set accuracy =  0.378213153063
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00626305916267
# abs gradients dW1 0.00015055389966
#
# ************
# start batch 15016 iter 560
# COST 1.8080585418
# alpha 0.0025
# ************
# train accuracy =  0.007
# validation set accuracy =  0.371661659155
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0115245120778
# abs gradients dW1 0.000233743542398
#
# ************
# start batch 29256 iter 580
# COST 1.85456297275
# alpha 0.0025
# ************
# train accuracy =  0.002
# validation set accuracy =  0.372433650476
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00757767440131
# abs gradients dW1 0.000172223352477
#
# ************
# start batch 27737 iter 600
# COST 1.84191272338
# alpha 0.00125
# ************
# train accuracy =  0.007
# validation set accuracy =  0.382719913203
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00608626634255
# abs gradients dW1 0.00012702266518
# ************
# start batch 21995 iter 620
# COST 1.82793847783
# alpha 0.00125
# ************
# train accuracy =  0.01
# validation set accuracy =  0.382970288766
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00441218632179
# abs gradients dW1 8.88006029645e-05
#
# ************
# start batch 31910 iter 640
# COST 1.83130042414
# alpha 0.00125
# ************
# train accuracy =  0.005
# validation set accuracy =  0.38326239359
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00631975689032
# abs gradients dW1 0.000150636130649
#
# ************
# start batch 22175 iter 660
# COST 1.80166081314
# alpha 0.00125
# ************
# train accuracy =  0.008
# validation set accuracy =  0.38176014021
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.006790657071
# abs gradients dW1 0.0001753188505
#
# ************
# start batch 5378 iter 680
# COST 1.78813881719
# alpha 0.00125
# ************
# train accuracy =  0.008
# validation set accuracy =  0.384514271407
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00641822176724
# abs gradients dW1 0.000144658237059
#
# ************
# start batch 46746 iter 700
# COST 1.81759396651
# alpha 0.00125
# ************
# train accuracy =  0.007
# validation set accuracy =  0.379715406443
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0061419528531
# abs gradients dW1 0.000126111923509
#
# ************
# start batch 39278 iter 720
# COST 1.78005718141
# alpha 0.00125
# ************
# train accuracy =  0.007
# validation set accuracy =  0.382093974295
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00578619965655
# abs gradients dW1 0.000146764316091
#
# ************
# start batch 35923 iter 740
# COST 1.82135563345
# alpha 0.00125
# ************
# train accuracy =  0.013
# validation set accuracy =  0.384243031213
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00652882101269
# abs gradients dW1 0.000137150176244
#
# ************
# start batch 11561 iter 760
# COST 1.79427223663
# alpha 0.00125
# ************
# train accuracy =  0.007
# validation set accuracy =  0.385787013854
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.00518112379478
# abs gradients dW1 0.000125082195576

# %%
layer_dimensions = [X_train.shape[0],15,32,12, 10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=4000, alpha=.001, batch_size=500, print_every=200)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2', 'W3', 'b3', 'W4', 'b4'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 13799
# COST 2.30177012114
# ************
# train accuracy =  0.092
# validation set accuracy =  0.100215062832
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0094639449027
# abs gradients dW3 0.000221988704063
# abs gradients dW2 1.14464624916e-05
# abs gradients dW1 3.66719967928e-07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-195-434158bdb34e> in <module>()
#       1 layer_dimensions = [X_train.shape[0],15,32,12, 10]  # including the input and output layers
#       2 NN = NeuralNetwork(layer_dimensions)
# ----> 3 NN.train(X_train, y_train, iters=4000, alpha=.001, batch_size=500, print_every=200)
#
# <ipython-input-194-46ad198d86ce> in train(self, X, y, iters, alpha, batch_size, print_every)
#     300
#     301             # forward prop
# --> 302             last_layer, cache = self.forwardPropagation(batch_x)
#     303             # compute loss
#     304             cost, cost_deriv = self.costFunction(last_layer, batch_y)
#
# <ipython-input-194-46ad198d86ce> in forwardPropagation(self, X)
#     110             layer_cache = {}
#     111             layer_cache["linear"] = [A,  self.parameters["W" + str(l)], self.parameters["b" + str(l)]]
# --> 112             Z, cache_l = self.affineForward(A, self.parameters["W" + str(l)], self.parameters["b" + str(l)])
#     113 #             print("forward, layer", l)
#     114 # #             print("forward shapes: Z, ", Z.shape)
#
# <ipython-input-194-46ad198d86ce> in affineForward(self, A_, W_, b_)
#      47 #         print("forward, shape A", A_.shape)
#      48 #         print("forward, shape b", b_.shape)
# ---> 49         return np.dot(W_, A_) + b_, [A_, W_, b_]
#      50
#      51
#
# KeyboardInterrupt:

# %%
layer_dimensions = [X_train.shape[0],4000, 2000, 10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=4000, alpha=.0001, batch_size=500, print_every=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-209-8b3c8007363e> in <module>()
#       1 layer_dimensions = [X_train.shape[0],4000, 2000, 10]  # including the input and output layers
# ----> 2 NN = NeuralNetwork(layer_dimensions)
#       3 NN.train(X_train, y_train, iters=4000, alpha=.0001, batch_size=500, print_every=10)
#
# <ipython-input-208-0db4ff6674a8> in __init__(self, layer_dimensions, drop_prob, reg_lambda)
#      21         # init parameters
#      22         for l in range(1, self.num_layers):
# ---> 23             self.parameters['W' + str(l)] = np.random.normal(size=(layer_dimensions[l], layer_dimensions[l-1]))  * 1/sqrt(layer_dimensions[l-1])
#      24             self.parameters['b' + str(l)]= np.ones((layer_dimensions[l], 1))
#      25
#
# NameError: name 'sqrt' is not defined

# %%
y_predicted = NN.predict(X_test)
save_predictions('ans1-uni', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans1-uni.npy')
print(loaded_y.shape)
loaded_y[:10]

# %% [markdown]
# ## Part 2: Regularizing the neural network
# #### Add dropout and L2 regularization

# %%
NN2 = NeuralNetwork(layer_dimensions, drop_prob=0, reg_lambda=0)
NN2.train(X_train, y_train, iters=100, alpha=0.05, batch_size=1000, print_every=1)

# %%
y_predicted2 = NN2.predict(X)
save_predictions(y_predicted, 'ans2-uni')

# %%
test = np.random.randint(10, size=(6))
test
# Out:
# array([5, 0, 3, 3, 7, 9])

# %%
T = one_hot(test)
T

# %%
np.random.randint(10)
# Out:
# 3
