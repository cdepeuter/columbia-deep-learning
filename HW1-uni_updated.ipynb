# %% [markdown]
# # COMS 4995_002 Deep Learning Assignment 1
# Due on Monday, Oct 9, 11:59pm
#
# This assignment can be done in groups of at most 3 students. Everyone must submit on Courseworks individually.

# %% [markdown]
# Write down the UNIs of your group (if applicable)
#
# Member 1: Name, UNI
#
# Member 2: Name, UNI
#
# Member 3: Name, UNI

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
# you shouldn't need to make any more imports

# %%
class NeuralNetwork(object):
    """
    Abstraction of neural network.
    Stores parameters, activations, cached values. 
    Provides necessary functions for training and prediction. 
    """
    def __init__(self, layer_dimensions, drop_prob=0.0, reg_lambda=0.0):
        """
        Initializes the weights and biases for each layer
        :param layer_dimensions: (list) number of nodes in each layer
        :param drop_prob: drop probability for dropout layers. Only required in part 2 of the assignment
        :param reg_lambda: regularization parameter. Only required in part 2 of the assignment
        """
        
        eps = .01
        self.parameters = {'layer_dimensions':layer_dimensions, 'drop_prob':drop_prob, 'reg_lambda':reg_lambda} 
        self.num_layers = len(layer_dimensions)
        self.drop_prob = drop_prob
        self.reg_lambda = reg_lambda
        
        # init parameters
        for l in range(1, self.num_layers):
            self.parameters['W' + str(l)] = np.random.normal(size=(layer_dimensions[l], layer_dimensions[l-1]))  * 1/np.sqrt(layer_dimensions[l-1])
            self.parameters['b' + str(l)]= np.ones((layer_dimensions[l], 1))
    
        # print all params:
        print(self.parameters.keys())

        
#     def gradientCheck(self, theta, x):
#         eps = 1e-7
#         J_pos = J(theta + eps, x)
#         J_neg = J(theta - eps, x)
#         numerical_deriv = (J_pos - J-neg)/(2*eps)
#         analytic_deriv = JDeriv(theta, x)
#         error = norm(numerical_deriv-analyic_deriv)/norm()
#         return error
        
    def affineForward(self, A_, W_, b_):
        """
        Forward pass for the affine layer.
        :param A: input matrix, shape (L, S), where L is the number of hidden units in the previous layer and S is
        the number of samples
        :returns: the affine product WA + b, along with the cache required for the backward pass
        """
#         print("forward, shape W", W_.shape)
#         print("forward, shape A", A_.shape)
#         print("forward, shape b", b_.shape)
        return np.dot(W_, A_) + b_, [A_, W_, b_]
        

    def activationForward(self, A_, activation="relu"):
        """
        Common interface to access all activation functions.
        :param A: input to the activation function
        :param prob: activation funciton to apply to A. Just "relu" for this assignment.
        :returns: activation(A)
        """ 
        
        if activation == "relu":
            return self.relu(A_)
        if activation == "softmax":
            return self.softmax(A_)
        
        return A_

    def softmax(self, x):
        # softmax
        
        e_x = np.exp(x - np.max(x,axis=0))
        return e_x / e_x.sum( axis=0)
    
    def relu(self, X):
        return np.maximum(0,X)
            
    def dropout(self, A, prob):
        """
        :param A: 
        :param prob: drop prob
        :returns: tuple (A, M) 
            WHERE
            A is matrix after applying dropout
            M is dropout mask, used in the backward pass
        """
        
        # make a mask, binary mask
        # where that mask is 0, drop those activation units
        # where its one, scale them up by 1/(1-p)
        # in forward we need to apply this mask
        
        M = np.random.binomial([np.ones(A.shape)],1-prob)[0] * (1.0/(1-prob))
        A = np.multiply(A *(1/(1-prob)), M)
        
        return A, M

    def forwardPropagation(self, X, training=False):
        """
        Runs an input X through the neural network to compute activations
        for all layers. Returns the output computed at the last layer along
        with the cache required for backpropagation.
        :returns: (tuple) AL, cache
            WHERE 
            AL is activation of last layer
            cache is cached values for each layer that
                     are needed in further steps
        """
        cache = {}
        A = X
        
        for l in range(1, self.num_layers):
            
            layer_cache = {}
            layer_cache["linear"] = [A,  self.parameters["W" + str(l)], self.parameters["b" + str(l)]]
            Z, cache_l = self.affineForward(A, self.parameters["W" + str(l)], self.parameters["b" + str(l)])
            if l != self.num_layers - 1:
                cache_a = self.activationForward(Z)
                if self.drop_prob > 0:
                    cache_a, dropout_mask = self.dropout(cache_a, self.drop_prob)
                    layer_cache['dropout'] = dropout_mask
            else:
                cache_a = Z
            
            
            
            layer_cache['activation'] = cache_a
            cache[str(l)] = layer_cache
            
            A = cache_a
        
        return A, cache
    
    def costFunction(self, AL, y):
        """
        :param AL: Activation of last layer, shape (num_classes, S)
        :param y: labels, shape (S)
        :param alpha: regularization parameter
        :returns cost, dAL: A scalar denoting cost and the gradient of cost
        """

        # softmax
        
        AL = self.softmax(AL)
        # compute loss
        #+ np.multiply((1-Y), np.log(1-preds))
        # one hot encode true labels
        # only look at how close we are to previous labels
        true_labels = one_hot(y)

        
        y_hat = AL[y, range(y.shape[0])]
        #print("preds", y_hat)
        cost = -np.sum(np.log(y_hat))/ AL.shape[1]
        
        if self.reg_lambda > 0:
            # add regularization
            pass
        
        # gradient of cost, should be same shape as input
        # 
        #dAL = -np.divide(true_labels, AL) 
        dAL = AL - true_labels
        return cost, dAL

    def affineBackward(self, dA_prev, cache):
        """
        Backward pass for the affine layer.
        :param dA_prev: gradient from the next layer.
        :param cache: cache returned in affineForward
        :returns dA: gradient on the input to this layer
                 dW: gradient on the weights
                 db: gradient on the bias
        """
        A, W, b = cache['linear']
        #output_last_layer = cache[str(layer-1)]['activation']

     
        dW = (1/A.shape[1]) * np.dot(dA_prev,A.T)
        db = (1/A.shape[1]) * np.sum(dA_prev, axis=1, keepdims=True)
        
        dA_prev = np.dot(W.T,dA_prev)
        return dA_prev, dW, db

    def activationBackward(self, dA, cache, activation="relu"):
        """
        Interface to call backward on activation functions.
        In this case, it's just relu. 
        """
        
        #dzl = dAl*gl_p(zl)
        # only passed in the cached linear layer
        
        # zl is avation at layer l, inputted as cache
       
        zl = cache['activation']
        
        # dA is derivative last layer, first time it will be cost
        return np.multiply(dA , self.relu_derivative(zl, dA))
        
    def relu_derivative(self, cached_x, dx):
        """
        Inputs:
        dx: upstream derivative
        cached_x: input of relu

        Returns:
        dx: gradient with respect to cached_x
        """
        # this should act element-wise as well
        # if cached_x is greater than 0, then the deriv is 1.0
        # if not, then the deriv is 0
#         print("\n\nrelu deriv shape dX", dx.shape)
#         print("relu deriv, shape cached_x", cached_x.shape)
#         print("\n\n")
        
        return 1.0 * (cached_x > 0)

    def dropout_backward(self, dA, cache):

        # in backwards we need to apply that mask to the derivatives
        # so cache here contains the dropout mask you used in forward prop
        mask = cache['dropout']
        p = self.drop_prob
        return np.multiply((1/(1-p)) * dA, mask)

    def backPropagation(self, dAL, cache):
        """
        Run backpropagation to compute gradients on all paramters in the model
        :param dAL: gradient on the last layer of the network. Returned by the cost function.
        :param Y: labels
        :param cache: cached values during forwardprop
        :returns gradients: dW and db for each weight/bias
        """
        gradients = {}
        dA_prev = dAL
        
        for l in range(self.num_layers-1, 0, -1):
            cached_l = cache[str(l)]
            if l != self.num_layers - 1:
                dA_prev = self.activationBackward(dA_prev, cached_l)
    
            # affine backwards
            
            dA, dW, db = self.affineBackward(dA_prev ,cached_l)
            gradients["dW" + str(l)] = dW
            gradients["db" + str(l)] = db
#             print("shapes: dA", dA.shape)
#             print("shapes: dW", dW.shape)
#             print("shapes: db", db.shape)
#             print("\n\n")
            
            if l != self.num_layers - 1 and self.drop_prob > 0:
                #call dropout_backward
                dA_prev = self.dropout_backward(dA, cached_l)
            else:
                dA_prev = dA
            
            
        if self.reg_lambda > 0:
            # add gradients from L2 regularization to each dW
            pass
        
        return gradients


    def updateParameters(self, gradients, alpha):
        """
        :param gradients: gradients for each weight/bias
        :param alpha: step size for gradient descent 
        """
        for l in range(1, self.num_layers):
            self.parameters["W" + str(l)] = self.parameters["W" + str(l)] - alpha * gradients["dW" + str(l)]
            self.parameters["b" + str(l)] = self.parameters["b" + str(l)] - alpha * gradients["db" + str(l)]
            
    def train(self, X, y, iters=1000, alpha=0.0001, batch_size=100, print_every=100):
        """
        :param X: input samples, each column is a sample
        :param y: labels for input samples, y.shape[0] must equal X.shape[1]
        :param iters: number of training iterations
        :param alpha: step size for gradient descent
        :param batch_size: number of samples in a minibatch
        :param print_every: no. of iterations to print debug info after
        """
        # we should get validation
        validation_X = X[:,X.shape[0]-batch_size:]
        validation_y = y[X.shape[0]-batch_size:]
        
        print("X train shape:", X_train.shape)
        print("y train shape:", y_train.shape)
        # get minibatch
#        
#         print("batch 1 x, shape:", batch_x.shape)
        #np.random.seed(0)
        # should we change alpha each step?
        

        
        
        for i in range(0, iters):
           
            start_batch = np.random.randint(X_train.shape[1] - 2*batch_size)
            #start_batch = 0
            batch_x, batch_y = self.get_batch(X, y, batch_size,start_batch)
            
            # forward prop
            last_layer, cache = self.forwardPropagation(batch_x, training=True)
            # compute loss
            cost, cost_deriv = self.costFunction(last_layer, batch_y)

            # compute gradients
            gradients = self.backPropagation(cost_deriv, cache)

            # update weights and biases based on gradient
            self.updateParameters(gradients, alpha)

            if i % print_every == 0:
                # print cost, train and validation set accuracies
                if i % 400 == 0 and i != 0:
                    alpha /= 2
                print("\n************")
                print("start batch", start_batch, "iter", i)
                print("COST", cost)
                print("alpha", alpha)
                print("************")
                #preds = self.predict(batch_x)
                preds = np.argmax(last_layer, axis=0)
                print("train accuracy = ", np.mean(preds == batch_y))
                preds_y = self.predict(validation_X)
                #print(gradients)
                print("validation set accuracy = ", np.mean(preds_y == validation_y))
                # delta gradients
                print(gradients.keys())
                #print(cost_deriv)
                for d in range(self.num_layers-1, 0, -1):
                    print("abs gradients dW"+str(d),np.mean(np.abs(gradients["dW"+str(d)])))
                
    def predict(self, X_):
        """
        Make predictions for each sample
        """
        
        forward, _ = self.forwardPropagation(X_, training=False)
        preds_ = np.argmax(forward, axis=0)
        
        return preds_

    def get_batch(self, X_, y_, batch_size, start_batch):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        # are minibatches random
        #get random set
        ix = np.random.choice(X_.shape[1], batch_size, replace=True)
        X_batch = X_[:,ix]
        y_batch = y_[ix]
        return X_batch, y_batch

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((num_classes, y.shape[0]))
    y_one_hot[y, range(y.shape[0])] = 1
    return y_one_hot

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0

    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)

# %%
# Load the data
data_root_path = 'cifar10-hw1/'
#X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
#X_test = get_images(data_root_path + 'test')
print('Data loading done')
# Out:
# {'airplane': 0, 'automobile': 1, 'bird': 2, 'cat': 3, 'deer': 4, 'dog': 5, 'frog': 6, 'horse': 7, 'ship': 8, 'truck': 9}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %% [markdown]
# ## Part 1
#
# #### Simple fully-connected deep neural network

# %%
# layer_dimensions = [X_train.shape[0],4000, 2000, 10]  # including the input and output layers
# NN = NeuralNetwork(layer_dimensions)
# NN.train(X_train, y_train, iters=4000, alpha=.0001, batch_size=500, print_every=10)

# %%
layer_dimensions = [X_train.shape[0],6144, 6144,10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=4000, alpha=.003, batch_size=500, print_every=20)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2', 'W3', 'b3'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 4169 iter 0
# COST 3.2567012627
# alpha 0.003
# ************
# train accuracy =  0.102
# validation set accuracy =  0.102428944927
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.124809281071
# abs gradients dW2 0.00459565454491
# abs gradients dW1 0.00220292659389
#
# ************
# start batch 7749 iter 20
# COST 7.70973789921
# alpha 0.003
# ************
# train accuracy =  0.156
# validation set accuracy =  0.110609766383
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.112654505759
# abs gradients dW2 0.00351548357342
# abs gradients dW1 0.00180864455365
#
# ************
# start batch 17857 iter 40
# COST 2.83504815555
# alpha 0.003
# ************
# train accuracy =  0.164
# validation set accuracy =  0.185228135279
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0604606872855
# abs gradients dW2 0.00206860674865
# abs gradients dW1 0.00108633629581
#
# ************
# start batch 22439 iter 60
# COST 2.87864765029
# alpha 0.003
# ************
# train accuracy =  0.176
# validation set accuracy =  0.199671080374
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0541260978802
# abs gradients dW2 0.00202267816428
# abs gradients dW1 0.00111637352881
#
# ************
# start batch 24231 iter 80
# COST 2.78646250467
# alpha 0.003
# ************
# train accuracy =  0.222
# validation set accuracy =  0.238867335751
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0530658462272
# abs gradients dW2 0.0020981996417
# abs gradients dW1 0.00110637377533
#
# ************
# start batch 9738 iter 100
# COST 2.3321108763
# alpha 0.003
# ************
# train accuracy =  0.272
# validation set accuracy =  0.2463312811
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0363766424453
# abs gradients dW2 0.00148717570802
# abs gradients dW1 0.000774172870393
#
# ************
# start batch 37509 iter 120
# COST 2.33081666092
# alpha 0.003
# ************
# train accuracy =  0.18
# validation set accuracy =  0.289069747828
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0426843800582
# abs gradients dW2 0.00198982658369
# abs gradients dW1 0.00109887077487
#
# ************
# start batch 7387 iter 140
# COST 2.26075975813
# alpha 0.003
# ************
# train accuracy =  0.228
# validation set accuracy =  0.207915155604
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0330202084128
# abs gradients dW2 0.00149894349771
# abs gradients dW1 0.000798209228693
#
# ************
# start batch 16647 iter 160
# COST 2.09724896325
# alpha 0.003
# ************
# train accuracy =  0.242
# validation set accuracy =  0.259024205111
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0220710867498
# abs gradients dW2 0.000989529867274
# abs gradients dW1 0.000570203862788
#
# ************
# start batch 36217 iter 180
# COST 2.13522306259
# alpha 0.003
# ************
# train accuracy =  0.26
# validation set accuracy =  0.28664501982
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0292546370181
# abs gradients dW2 0.00137267682373
# abs gradients dW1 0.000728103336177
#
# ************
# start batch 8018 iter 200
# COST 2.00230131479
# alpha 0.003
# ************
# train accuracy =  0.264
# validation set accuracy =  0.285401028928
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0204878254641
# abs gradients dW2 0.000946857680177
# abs gradients dW1 0.000535919353087
#
# ************
# start batch 22904 iter 220
# COST 2.16144005871
# alpha 0.003
# ************
# train accuracy =  0.294
# validation set accuracy =  0.274057518765
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0251950815317
# abs gradients dW2 0.00112755630993
# abs gradients dW1 0.000573954903659
#
# ************
# start batch 17441 iter 240
# COST 2.10361934229
# alpha 0.003
# ************
# train accuracy =  0.234
# validation set accuracy =  0.282512439909
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0278224219765
# abs gradients dW2 0.00138397853946
# abs gradients dW1 0.000766211060044
#
# ************
# start batch 19598 iter 260
# COST 1.99929050713
# alpha 0.003
# ************
# train accuracy =  0.298
# validation set accuracy =  0.273699080712
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0207865837523
# abs gradients dW2 0.000932955798829
# abs gradients dW1 0.000533679392493
#
# ************
# start batch 20735 iter 280
# COST 2.04407813191
# alpha 0.003
# ************
# train accuracy =  0.294
# validation set accuracy =  0.320780973265
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0241202750147
# abs gradients dW2 0.00117861996314
# abs gradients dW1 0.000687446691382
#
# ************
# start batch 42307 iter 300
# COST 1.91264749772
# alpha 0.003
# ************
# train accuracy =  0.326
# validation set accuracy =  0.274352703045
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0164549558403
# abs gradients dW2 0.000872010236621
# abs gradients dW1 0.000473197738336
#
# ************
# start batch 37259 iter 320
# COST 1.97243202858
# alpha 0.003
# ************
# train accuracy =  0.288
# validation set accuracy =  0.308678417812
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0184071713182
# abs gradients dW2 0.000852407348793
# abs gradients dW1 0.00047542657116
#
# ************
# start batch 14855 iter 340
# COST 1.95058407355
# alpha 0.003
# ************
# train accuracy =  0.358
# validation set accuracy =  0.319136375137
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.013122967583
# abs gradients dW2 0.000721418317494
# abs gradients dW1 0.000419764189623
#
# ************
# start batch 17710 iter 360
# COST 1.95917268575
# alpha 0.003
# ************
# train accuracy =  0.296
# validation set accuracy =  0.33018470102
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0187846758559
# abs gradients dW2 0.000904431181947
# abs gradients dW1 0.000460487732821
#
# ************
# start batch 28496 iter 380
# COST 1.89196063979
# alpha 0.003
# ************
# train accuracy =  0.358
# validation set accuracy =  0.29689213123
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0160042176525
# abs gradients dW2 0.000801108782706
# abs gradients dW1 0.000448193801787
#
# ************
# start batch 13374 iter 400
# COST 1.89520070727
# alpha 0.0015
# ************
# train accuracy =  0.326
# validation set accuracy =  0.322425571392
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0190895469947
# abs gradients dW2 0.000921957126727
# abs gradients dW1 0.00051168216776
#
# ************
# start batch 27324 iter 420
# COST 1.82178183073
# alpha 0.0015
# ************
# train accuracy =  0.382
# validation set accuracy =  0.37323943662
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.006283671953
# abs gradients dW2 0.000345309143324
# abs gradients dW1 0.000209704938812
#
# ************
# start batch 12996 iter 440
# COST 1.78838397979
# alpha 0.0015
# ************
# train accuracy =  0.366
# validation set accuracy =  0.369865901999
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00933540672734
# abs gradients dW2 0.000472901606606
# abs gradients dW1 0.000276074528532
#
# ************
# start batch 30803 iter 460
# COST 1.79851015209
# alpha 0.0015
# ************
# train accuracy =  0.39
# validation set accuracy =  0.374673188834
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00671988028552
# abs gradients dW2 0.000335204381808
# abs gradients dW1 0.000182311879001
#
# ************
# start batch 36473 iter 480
# COST 1.79593245966
# alpha 0.0015
# ************
# train accuracy =  0.4
# validation set accuracy =  0.370983385342
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00677378592713
# abs gradients dW2 0.000382578767453
# abs gradients dW1 0.000245083015272
#
# ************
# start batch 1969 iter 500
# COST 1.81797587987
# alpha 0.0015
# ************
# train accuracy =  0.39
# validation set accuracy =  0.377393101122
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00865989961691
# abs gradients dW2 0.000428985089491
# abs gradients dW1 0.000253612990365
# ************
# start batch 4973 iter 520
# COST 1.87013645844
# alpha 0.0015
# ************
# train accuracy =  0.342
# validation set accuracy =  0.371341823395
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00650870119592
# abs gradients dW2 0.000375105406072
# abs gradients dW1 0.000191858963336
#
# ************
# start batch 34944 iter 540
# COST 1.81316988351
# alpha 0.0015
# ************
# train accuracy =  0.358
# validation set accuracy =  0.374272581597
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.005745157104
# abs gradients dW2 0.000316764241306
# abs gradients dW1 0.00019478927327
#
# ************
# start batch 45380 iter 560
# COST 1.84545406315
# alpha 0.0015
# ************
# train accuracy =  0.342
# validation set accuracy =  0.374082820275
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00667451721421
# abs gradients dW2 0.000347401692742
# abs gradients dW1 0.000203989945755
#
# ************
# start batch 3763 iter 580
# COST 1.78541323792
# alpha 0.0015
# ************
# train accuracy =  0.388
# validation set accuracy =  0.380218436367
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00601836814773
# abs gradients dW2 0.000317694986055
# abs gradients dW1 0.000158836721681
#
# ************
# start batch 12451 iter 600
# COST 1.81263426465
# alpha 0.0015
# ************
# train accuracy =  0.38
# validation set accuracy =  0.38118832757
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00495755896482
# abs gradients dW2 0.000295636820932
# abs gradients dW1 0.000189949034655
#
# ************
# start batch 20146 iter 620
# COST 1.81040644404
# alpha 0.0015
# ************
# train accuracy =  0.394
# validation set accuracy =  0.378953360884
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00697089947566
# abs gradients dW2 0.000367783554638
# abs gradients dW1 0.000182471406669
#
# ************
# start batch 14305 iter 640
# COST 1.83929330089
# alpha 0.0015
# ************
# train accuracy =  0.356
# validation set accuracy =  0.376275617779
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00717474269528
# abs gradients dW2 0.000349315887757
# abs gradients dW1 0.00019379286292
#
# ************
# start batch 18921 iter 660
# COST 1.86494761335
# alpha 0.0015
# ************
# train accuracy =  0.344
# validation set accuracy =  0.377245508982
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0069811706919
# abs gradients dW2 0.000450207911646
# abs gradients dW1 0.000267388610975
#
# ************
# start batch 33041 iter 680
# COST 1.76281768107
# alpha 0.0015
# ************
# train accuracy =  0.382
# validation set accuracy =  0.38118832757
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.007086326176
# abs gradients dW2 0.000409688756993
# abs gradients dW1 0.000247499534868
#
# ************
# start batch 31016 iter 700
# COST 1.71750756239
# alpha 0.0015
# ************
# train accuracy =  0.404
# validation set accuracy =  0.381293750527
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00444470580913
# abs gradients dW2 0.000245948470313
# abs gradients dW1 0.000148203595382
#
# ************
# start batch 15669 iter 720
# COST 1.76708632342
# alpha 0.0015
# ************
# train accuracy =  0.408
# validation set accuracy =  0.385869106857
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00689503380194
# abs gradients dW2 0.000348799459513
# abs gradients dW1 0.000196990684091
#
# ************
# start batch 8202 iter 740
# COST 1.76741212218
# alpha 0.0015
# ************
# train accuracy =  0.39
# validation set accuracy =  0.386775744286
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00531808836896
# abs gradients dW2 0.000285618537944
# abs gradients dW1 0.000170963341542
#
# ************
# start batch 16050 iter 760
# COST 1.75920472193
# alpha 0.0015
# ************
# train accuracy =  0.392
# validation set accuracy =  0.381757611537
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00554876443627
# abs gradients dW2 0.000301718989361
# abs gradients dW1 0.000171344847768
#
# ************
# start batch 22789 iter 780
# COST 1.80347741844
# alpha 0.0015
# ************
# train accuracy =  0.37
# validation set accuracy =  0.384688369739
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00569713892212
# abs gradients dW2 0.000299281326322
# abs gradients dW1 0.000179569203256
#
# ************
# start batch 12147 iter 800
# COST 1.79554830866
# alpha 0.00075
# ************
# train accuracy =  0.362
# validation set accuracy =  0.385637176352
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00502556358771
# abs gradients dW2 0.000267866598233
# abs gradients dW1 0.00014581132156
#
# ************
# start batch 5157 iter 820
# COST 1.78631350257
# alpha 0.00075
# ************
# train accuracy =  0.392
# validation set accuracy =  0.389854094628
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00413499865881
# abs gradients dW2 0.000249562226385
# abs gradients dW1 0.000164330200967
#
# ************
# start batch 12692 iter 840
# COST 1.84547963172
# alpha 0.00075
# ************
# train accuracy =  0.362
# validation set accuracy =  0.387703466307
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00529925637363
# abs gradients dW2 0.000282671578711
# abs gradients dW1 0.000164847901662
#
# ************
# start batch 29501 iter 860
# COST 1.77651265449
# alpha 0.00075
# ************
# train accuracy =  0.4
# validation set accuracy =  0.391351100616
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00614314268341
# abs gradients dW2 0.000314451658008
# abs gradients dW1 0.000180890159749
#
# ************
# start batch 13664 iter 880
# COST 1.77297034312
# alpha 0.00075
# ************
# train accuracy =  0.402
# validation set accuracy =  0.389685417897
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00656233353044
# abs gradients dW2 0.00032530254907
# abs gradients dW1 0.000165852555816
#
# ************
# start batch 4098 iter 900
# COST 1.79024654905
# alpha 0.00075
# ************
# train accuracy =  0.364
# validation set accuracy =  0.39278485283
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00529552095516
# abs gradients dW2 0.000263896730848
# abs gradients dW1 0.00015714631531
#
# ************
# start batch 41032 iter 920
# COST 1.78305492793
# alpha 0.00075
# ************
# train accuracy =  0.39
# validation set accuracy =  0.390022771359
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00563916464684
# abs gradients dW2 0.000336293759939
# abs gradients dW1 0.000226256980946
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-226-f97dec72f601> in <module>()
#       1 layer_dimensions = [X_train.shape[0],6144, 6144,10]  # including the input and output layers
#       2 NN = NeuralNetwork(layer_dimensions)
# ----> 3 NN.train(X_train, y_train, iters=4000, alpha=.003, batch_size=500, print_every=20)
#
# <ipython-input-224-65804106928b> in train(self, X, y, iters, alpha, batch_size, print_every)
#     318
#     319             # update weights and biases based on gradient
# --> 320             self.updateParameters(gradients, alpha)
#     321
#     322             if i % print_every == 0:
#
# <ipython-input-224-65804106928b> in updateParameters(self, gradients, alpha)
#     276         """
#     277         for l in range(1, self.num_layers):
# --> 278             self.parameters["W" + str(l)] = self.parameters["W" + str(l)] - alpha * gradients["dW" + str(l)]
#     279             self.parameters["b" + str(l)] = self.parameters["b" + str(l)] - alpha * gradients["db" + str(l)]
#     280
#
# KeyboardInterrupt:

# %%
layer_dimensions = [X_train.shape[0],9200, 3072,10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=1000, alpha=.003, batch_size=200, print_every=20)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2', 'W3', 'b3'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 8480 iter 0
# COST 3.52787601698
# alpha 0.003
# ************
# train accuracy =  0.09
# validation set accuracy =  0.099664742828
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.128781521439
# abs gradients dW2 0.00491939177519
# abs gradients dW1 0.00131074271401
#
# ************
# start batch 22661 iter 20
# COST 3.65744249322
# alpha 0.003
# ************
# train accuracy =  0.14
# validation set accuracy =  0.136564250552
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.049895746763
# abs gradients dW2 0.00228176705527
# abs gradients dW1 0.000752546291412
#
# ************
# start batch 10515 iter 40
# COST 2.57193766292
# alpha 0.003
# ************
# train accuracy =  0.175
# validation set accuracy =  0.184943133594
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0418304013458
# abs gradients dW2 0.00210323353955
# abs gradients dW1 0.000699515672926
#
# ************
# start batch 30489 iter 60
# COST 2.57918581167
# alpha 0.003
# ************
# train accuracy =  0.185
# validation set accuracy =  0.133275335257
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0357133377061
# abs gradients dW2 0.00199098599255
# abs gradients dW1 0.000641186496679
#
# ************
# start batch 43027 iter 80
# COST 2.21981031064
# alpha 0.003
# ************
# train accuracy =  0.26
# validation set accuracy =  0.191117806824
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0282724305579
# abs gradients dW2 0.00171755347987
# abs gradients dW1 0.000567417646963
#
# ************
# start batch 25586 iter 100
# COST 2.11636872507
# alpha 0.003
# ************
# train accuracy =  0.195
# validation set accuracy =  0.240196910542
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0221009931967
# abs gradients dW2 0.00137238216302
# abs gradients dW1 0.000465953571352
#
# ************
# start batch 11535 iter 120
# COST 2.11317820485
# alpha 0.003
# ************
# train accuracy =  0.2
# validation set accuracy =  0.24471651672
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0243299314108
# abs gradients dW2 0.00157562955025
# abs gradients dW1 0.000507108475642
#
# ************
# start batch 22905 iter 140
# COST 2.04769538806
# alpha 0.003
# ************
# train accuracy =  0.28
# validation set accuracy =  0.256323204889
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0196615183332
# abs gradients dW2 0.00126652596807
# abs gradients dW1 0.000423664046494
#
# ************
# start batch 499 iter 160
# COST 2.15213526372
# alpha 0.003
# ************
# train accuracy =  0.165
# validation set accuracy =  0.264322695637
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0229464331905
# abs gradients dW2 0.0016483353716
# abs gradients dW1 0.00058093731317
#
# ************
# start batch 47812 iter 180
# COST 1.98544035858
# alpha 0.003
# ************
# train accuracy =  0.33
# validation set accuracy =  0.306739093533
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0167693363907
# abs gradients dW2 0.0012009736749
# abs gradients dW1 0.000387658473703
#
# ************
# start batch 26137 iter 200
# COST 2.03713752702
# alpha 0.003
# ************
# train accuracy =  0.305
# validation set accuracy =  0.271770497369
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0146736055336
# abs gradients dW2 0.00114870594478
# abs gradients dW1 0.00038541649452
#
# ************
# start batch 13416 iter 220
# COST 2.1473900956
# alpha 0.003
# ************
# train accuracy =  0.24
# validation set accuracy =  0.306887625191
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0175961685217
# abs gradients dW2 0.0012530689937
# abs gradients dW1 0.000404700647345
#
# ************
# start batch 10546 iter 240
# COST 2.24454968157
# alpha 0.003
# ************
# train accuracy =  0.225
# validation set accuracy =  0.285329315906
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0199080887315
# abs gradients dW2 0.00187331980987
# abs gradients dW1 0.000622132268702
#
# ************
# start batch 5120 iter 260
# COST 1.93274256349
# alpha 0.003
# ************
# train accuracy =  0.325
# validation set accuracy =  0.289212357834
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0102773086449
# abs gradients dW2 0.000822178898788
# abs gradients dW1 0.000293871328486
#
# ************
# start batch 43374 iter 280
# COST 2.06355601645
# alpha 0.003
# ************
# train accuracy =  0.255
# validation set accuracy =  0.285499066372
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0211313443696
# abs gradients dW2 0.00150852631582
# abs gradients dW1 0.000482909790782
#
# ************
# start batch 4244 iter 300
# COST 2.03312287315
# alpha 0.003
# ************
# train accuracy =  0.29
# validation set accuracy =  0.297784756408
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00953815447024
# abs gradients dW2 0.000806531900132
# abs gradients dW1 0.000260473473379
#
# ************
# start batch 29538 iter 320
# COST 2.01629093211
# alpha 0.003
# ************
# train accuracy =  0.265
# validation set accuracy =  0.296426752674
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0164970161336
# abs gradients dW2 0.00127237687704
# abs gradients dW1 0.000411437527633
#
# ************
# start batch 38568 iter 340
# COST 2.03457337416
# alpha 0.003
# ************
# train accuracy =  0.29
# validation set accuracy =  0.287875572908
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0158813303183
# abs gradients dW2 0.00131665586956
# abs gradients dW1 0.000455611840278
#
# ************
# start batch 41077 iter 360
# COST 1.94478530264
# alpha 0.003
# ************
# train accuracy =  0.295
# validation set accuracy =  0.302092174503
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0114263457205
# abs gradients dW2 0.000953051424831
# abs gradients dW1 0.00034481020097
#
# ************
# start batch 27848 iter 380
# COST 2.04230259134
# alpha 0.003
# ************
# train accuracy =  0.285
# validation set accuracy =  0.274359191988
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0150547892496
# abs gradients dW2 0.00109157017015
# abs gradients dW1 0.000359183939381
#
# ************
# start batch 11008 iter 400
# COST 1.81934924071
# alpha 0.0015
# ************
# train accuracy =  0.37
# validation set accuracy =  0.352020030555
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00724196822573
# abs gradients dW2 0.000601781448725
# abs gradients dW1 0.000195073785795
#
# ************
# start batch 10828 iter 420
# COST 1.83307664091
# alpha 0.0015
# ************
# train accuracy =  0.375
# validation set accuracy =  0.364433033441
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0083363672788
# abs gradients dW2 0.000654186002374
# abs gradients dW1 0.000234718634581
#
# ************
# start batch 29126 iter 440
# COST 1.84602570061
# alpha 0.0015
# ************
# train accuracy =  0.325
# validation set accuracy =  0.350046681378
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00998719098185
# abs gradients dW2 0.000765255073736
# abs gradients dW1 0.000270415633743
#
# ************
# start batch 43510 iter 460
# COST 1.88623901944
# alpha 0.0015
# ************
# train accuracy =  0.375
# validation set accuracy =  0.34977083687
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00884170019036
# abs gradients dW2 0.000693540140688
# abs gradients dW1 0.000235370874164
#
# ************
# start batch 25710 iter 480
# COST 1.83338570485
# alpha 0.0015
# ************
# train accuracy =  0.39
# validation set accuracy =  0.345611950433
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00921694271886
# abs gradients dW2 0.000798118891757
# abs gradients dW1 0.000267434168658
#
# ************
# start batch 30765 iter 500
# COST 1.84231038456
# alpha 0.0015
# ************
# train accuracy =  0.37
# validation set accuracy =  0.361207774571
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00786630907876
# abs gradients dW2 0.000726421983041
# abs gradients dW1 0.000230335858104
# ************
# start batch 7783 iter 520
# COST 1.87155607244
# alpha 0.0015
# ************
# train accuracy =  0.345
# validation set accuracy =  0.351043965371
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00507625157315
# abs gradients dW2 0.000506274937784
# abs gradients dW1 0.000187447390971
#
# ************
# start batch 18074 iter 540
# COST 1.81319384949
# alpha 0.0015
# ************
# train accuracy =  0.39
# validation set accuracy =  0.355521133933
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00694566226905
# abs gradients dW2 0.000573969928157
# abs gradients dW1 0.000202034127997
#
# ************
# start batch 3268 iter 560
# COST 1.82493477221
# alpha 0.0015
# ************
# train accuracy =  0.43
# validation set accuracy =  0.360401459854
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0080371942189
# abs gradients dW2 0.000668386334858
# abs gradients dW1 0.000228785392087
#
# ************
# start batch 25059 iter 580
# COST 1.8706213298
# alpha 0.0015
# ************
# train accuracy =  0.305
# validation set accuracy =  0.357388389068
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00925282447586
# abs gradients dW2 0.000846667936884
# abs gradients dW1 0.000289493962659
#
# ************
# start batch 44945 iter 600
# COST 1.84112897049
# alpha 0.0015
# ************
# train accuracy =  0.37
# validation set accuracy =  0.369780173145
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0107801230928
# abs gradients dW2 0.000881209931605
# abs gradients dW1 0.000288125257002
#
# ************
# start batch 38485 iter 620
# COST 1.92926665711
# alpha 0.0015
# ************
# train accuracy =  0.32
# validation set accuracy =  0.366979290443
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00832157320471
# abs gradients dW2 0.00069922082088
# abs gradients dW1 0.000223558877191
#
# ************
# start batch 45139 iter 640
# COST 1.90176493792
# alpha 0.0015
# ************
# train accuracy =  0.3
# validation set accuracy =  0.3653454422
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00850996141384
# abs gradients dW2 0.000715592368908
# abs gradients dW1 0.000247355406588
#
# ************
# start batch 22413 iter 660
# COST 1.79144853466
# alpha 0.0015
# ************
# train accuracy =  0.4
# validation set accuracy =  0.362289933797
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00633626539801
# abs gradients dW2 0.000550137077539
# abs gradients dW1 0.000209881076007
#
# ************
# start batch 35668 iter 680
# COST 1.85504484189
# alpha 0.0015
# ************
# train accuracy =  0.355
# validation set accuracy =  0.366597351893
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00572460670407
# abs gradients dW2 0.000494016385864
# abs gradients dW1 0.000192502907369
#
# ************
# start batch 33829 iter 700
# COST 1.80598078428
# alpha 0.0015
# ************
# train accuracy =  0.405
# validation set accuracy =  0.370586487863
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00865019100008
# abs gradients dW2 0.000744034667526
# abs gradients dW1 0.000252380894804
#
# ************
# start batch 29439 iter 720
# COST 1.93463050484
# alpha 0.0015
# ************
# train accuracy =  0.305
# validation set accuracy =  0.360847054829
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00977547525233
# abs gradients dW2 0.000820988127714
# abs gradients dW1 0.00028659923806
#
# ************
# start batch 16886 iter 740
# COST 1.76483391471
# alpha 0.0015
# ************
# train accuracy =  0.385
# validation set accuracy =  0.353356815481
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0072611631324
# abs gradients dW2 0.000681670235013
# abs gradients dW1 0.000230817094531
#
# ************
# start batch 39190 iter 760
# COST 1.8910408231
# alpha 0.0015
# ************
# train accuracy =  0.335
# validation set accuracy =  0.368867764386
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00856235239635
# abs gradients dW2 0.000730804357425
# abs gradients dW1 0.000251612771369
#
# ************
# start batch 7835 iter 780
# COST 1.81695944177
# alpha 0.0015
# ************
# train accuracy =  0.385
# validation set accuracy =  0.360528772704
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00575563332595
# abs gradients dW2 0.000464968524047
# abs gradients dW1 0.000157333290351
#
# ************
# start batch 21945 iter 800
# COST 1.8750640146
# alpha 0.00075
# ************
# train accuracy =  0.385
# validation set accuracy =  0.356751824818
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00659399889544
# abs gradients dW2 0.000595834938925
# abs gradients dW1 0.000187039587465
#
# ************
# start batch 46114 iter 820
# COST 1.83677872347
# alpha 0.00075
# ************
# train accuracy =  0.37
# validation set accuracy =  0.377206756069
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00671083089327
# abs gradients dW2 0.000691678732923
# abs gradients dW1 0.000211156162106
#
# ************
# start batch 9526 iter 840
# COST 1.76492803366
# alpha 0.00075
# ************
# train accuracy =  0.365
# validation set accuracy =  0.381365642506
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00540148515187
# abs gradients dW2 0.000499690930557
# abs gradients dW1 0.000177442883862
#
# ************
# start batch 18537 iter 860
# COST 1.77929374897
# alpha 0.00075
# ************
# train accuracy =  0.35
# validation set accuracy =  0.375424376167
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00602843434654
# abs gradients dW2 0.000514678637759
# abs gradients dW1 0.000184896878591
#
# ************
# start batch 792 iter 880
# COST 1.73469341667
# alpha 0.00075
# ************
# train accuracy =  0.395
# validation set accuracy =  0.381280767272
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00530190695008
# abs gradients dW2 0.000466385859807
# abs gradients dW1 0.000181354342602
#
# ************
# start batch 21958 iter 900
# COST 1.80246189718
# alpha 0.00075
# ************
# train accuracy =  0.41
# validation set accuracy =  0.365027160075
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00783179164054
# abs gradients dW2 0.000672112453815
# abs gradients dW1 0.000241182482007
#
# ************
# start batch 35796 iter 920
# COST 1.71160108068
# alpha 0.00075
# ************
# train accuracy =  0.445
# validation set accuracy =  0.376251909693
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00612698381037
# abs gradients dW2 0.000581031814945
# abs gradients dW1 0.000202826517077
#
# ************
# start batch 16431 iter 940
# COST 1.73443912068
# alpha 0.00075
# ************
# train accuracy =  0.43
# validation set accuracy =  0.380304702088
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0057155938373
# abs gradients dW2 0.000507899193674
# abs gradients dW1 0.000194586195518
#
# ************
# start batch 25118 iter 960
# COST 1.85040730452
# alpha 0.00075
# ************
# train accuracy =  0.38
# validation set accuracy =  0.381535392972
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00730093661621
# abs gradients dW2 0.000591788544234
# abs gradients dW1 0.000184894759847
#
# ************
# start batch 28710 iter 980
# COST 1.76933511087
# alpha 0.00075
# ************
# train accuracy =  0.385
# validation set accuracy =  0.375275844509
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00772489290008
# abs gradients dW2 0.000702874324989
# abs gradients dW1 0.000228875001978

# %%
layer_dimensions = [X_train.shape[0],3072, 3072,10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=1000, alpha=.003, batch_size=500, print_every=20)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2', 'W3', 'b3'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-234-727844aa4612> in <module>()
#       1 layer_dimensions = [X_train.shape[0],3072, 3072,10]  # including the input and output layers
#       2 NN = NeuralNetwork(layer_dimensions)
# ----> 3 NN.train(X_train, y_train, iters=1000, alpha=.003, batch_size=500, print_every=20)
#
# <ipython-input-224-65804106928b> in train(self, X, y, iters, alpha, batch_size, print_every)
#     307             start_batch = np.random.randint(X_train.shape[1] - 2*batch_size)
#     308             #start_batch = 0
# --> 309             batch_x, batch_y = self.get_batch(X, y, batch_size,start_batch)
#     310
#     311             # forward prop
#
# <ipython-input-224-65804106928b> in get_batch(self, X_, y_, batch_size, start_batch)
#     362         #get random set
#     363         ix = np.random.choice(X_.shape[1], batch_size, replace=True)
# --> 364         X_batch = X_[:,ix]
#     365         y_batch = y_[ix]
#     366         return X_batch, y_batch
#
# KeyboardInterrupt:

# %%
layer_dimensions = [X_train.shape[0],15000,10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=500, alpha=.001, batch_size=1000, print_every=20)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 28500 iter 0
# COST 3.01135033467
# alpha 0.001
# ************
# train accuracy =  0.093
# validation set accuracy =  0.103634618595
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0963681152166
# abs gradients dW1 0.00134736513366
#
# ************
# start batch 9773 iter 20
# COST 2.25621003281
# alpha 0.001
# ************
# train accuracy =  0.178
# validation set accuracy =  0.114567684861
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0210005148369
# abs gradients dW1 0.000258961250303
#
# ************
# start batch 10525 iter 40
# COST 2.22197459286
# alpha 0.001
# ************
# train accuracy =  0.196
# validation set accuracy =  0.185361375396
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0290820322303
# abs gradients dW1 0.000337921938262
#
# ************
# start batch 6732 iter 60
# COST 2.14608041935
# alpha 0.001
# ************
# train accuracy =  0.223
# validation set accuracy =  0.240840427308
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0190613426358
# abs gradients dW1 0.000241152828232
#
# ************
# start batch 36441 iter 80
# COST 2.15282394696
# alpha 0.001
# ************
# train accuracy =  0.235
# validation set accuracy =  0.226360373894
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0344285543777
# abs gradients dW1 0.000375655595592
#
# ************
# start batch 6486 iter 100
# COST 2.15252379973
# alpha 0.001
# ************
# train accuracy =  0.253
# validation set accuracy =  0.248414288099
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0347894024731
# abs gradients dW1 0.000389502113303
#
# ************
# start batch 27749 iter 120
# COST 2.05146300342
# alpha 0.001
# ************
# train accuracy =  0.273
# validation set accuracy =  0.255487397763
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.020955751082
# abs gradients dW1 0.000233546502608
#
# ************
# start batch 32167 iter 140
# COST 2.09415594448
# alpha 0.001
# ************
# train accuracy =  0.237
# validation set accuracy =  0.272763311634
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0245287128801
# abs gradients dW1 0.000301351411505
#
# ************
# start batch 5794 iter 160
# COST 2.05477127152
# alpha 0.001
# ************
# train accuracy =  0.252
# validation set accuracy =  0.265335503255
# dict_keys(['dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW2 0.0243826301747
# abs gradients dW1 0.000286918173085
#
# ************
# start batch 21351 iter 180
# COST 2.00796054186
# alpha 0.001
# ************
# train accuracy =  0.304
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-232-d35c6de0b96a> in <module>()
#       1 layer_dimensions = [X_train.shape[0],15000,10]  # including the input and output layers
#       2 NN = NeuralNetwork(layer_dimensions)
# ----> 3 NN.train(X_train, y_train, iters=500, alpha=.001, batch_size=1000, print_every=20)
#
# <ipython-input-224-65804106928b> in train(self, X, y, iters, alpha, batch_size, print_every)
#     332                 preds = np.argmax(last_layer, axis=0)
#     333                 print("train accuracy = ", np.mean(preds == batch_y))
# --> 334                 preds_y = self.predict(validation_X)
#     335                 #print(gradients)
#     336                 print("validation set accuracy = ", np.mean(preds_y == validation_y))
#
# <ipython-input-224-65804106928b> in predict(self, X_)
#     346         """
#     347
# --> 348         forward, _ = self.forwardPropagation(X_, training=False)
#     349         preds_ = np.argmax(forward, axis=0)
#     350
#
# <ipython-input-224-65804106928b> in forwardPropagation(self, X, training)
#     113             layer_cache = {}
#     114             layer_cache["linear"] = [A,  self.parameters["W" + str(l)], self.parameters["b" + str(l)]]
# --> 115             Z, cache_l = self.affineForward(A, self.parameters["W" + str(l)], self.parameters["b" + str(l)])
#     116 #             print("forward, layer", l)
#     117 # #             print("forward shapes: Z, ", Z.shape)
#
# <ipython-input-224-65804106928b> in affineForward(self, A_, W_, b_)
#      47 #         print("forward, shape A", A_.shape)
#      48 #         print("forward, shape b", b_.shape)
# ---> 49         return np.dot(W_, A_) + b_, [A_, W_, b_]
#      50
#      51
#
# KeyboardInterrupt:

# %%
layer_dimensions = [X_train.shape[0],1000,1000, 1000, 10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=500, alpha=.001, batch_size=500, print_every=20)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2', 'W3', 'b3', 'W4', 'b4'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 32716 iter 0
# COST 2.88244270501
# alpha 0.001
# ************
# train accuracy =  0.116
# validation set accuracy =  0.0926456945264
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.090012896713
# abs gradients dW3 0.00547038320724
# abs gradients dW2 0.00462144371347
# abs gradients dW1 0.00228296577998
#
# ************
# start batch 28349 iter 20
# COST 2.3000239672
# alpha 0.001
# ************
# train accuracy =  0.12
# validation set accuracy =  0.123450282534
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0110399230317
# abs gradients dW3 0.000841760685675
# abs gradients dW2 0.00078283129649
# abs gradients dW1 0.000497942309516
#
# ************
# start batch 32631 iter 40
# COST 2.25945748714
# alpha 0.001
# ************
# train accuracy =  0.148
# validation set accuracy =  0.132305810913
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0121188160681
# abs gradients dW3 0.000832926308471
# abs gradients dW2 0.00075963758295
# abs gradients dW1 0.000448763920748
#
# ************
# start batch 11160 iter 60
# COST 2.23647138368
# alpha 0.001
# ************
# train accuracy =  0.152
# validation set accuracy =  0.156785021506
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.019091636731
# abs gradients dW3 0.0012944690408
# abs gradients dW2 0.00109603436868
# abs gradients dW1 0.000673801793244
#
# ************
# start batch 18102 iter 80
# COST 2.21539582681
# alpha 0.001
# ************
# train accuracy =  0.162
# validation set accuracy =  0.182213038711
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0113392099739
# abs gradients dW3 0.000771368487547
# abs gradients dW2 0.000703820042957
# abs gradients dW1 0.00045175245422
#
# ************
# start batch 13924 iter 100
# COST 2.20259129376
# alpha 0.001
# ************
# train accuracy =  0.158
# validation set accuracy =  0.183520283377
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.017778127619
# abs gradients dW3 0.00125386807382
# abs gradients dW2 0.00109454113969
# abs gradients dW1 0.00054439710882
#
# ************
# start batch 13954 iter 120
# COST 2.18623116492
# alpha 0.001
# ************
# train accuracy =  0.188
# validation set accuracy =  0.187905878384
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0144988747687
# abs gradients dW3 0.00093366773129
# abs gradients dW2 0.000827964681198
# abs gradients dW1 0.00049288234916
#
# ************
# start batch 45491 iter 140
# COST 2.16011842879
# alpha 0.001
# ************
# train accuracy =  0.234
# validation set accuracy =  0.202770515307
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0187242429435
# abs gradients dW3 0.0013171179929
# abs gradients dW2 0.00104887728222
# abs gradients dW1 0.000523394300358
#
# ************
# start batch 48684 iter 160
# COST 2.15918622189
# alpha 0.001
# ************
# train accuracy =  0.206
# validation set accuracy =  0.216412245931
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.00700565368411
# abs gradients dW3 0.000541192494091
# abs gradients dW2 0.000534049407814
# abs gradients dW1 0.000344590950698
#
# ************
# start batch 37361 iter 180
# COST 2.1218747309
# alpha 0.001
# ************
# train accuracy =  0.23
# validation set accuracy =  0.236063085097
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0195741359931
# abs gradients dW3 0.00120018463339
# abs gradients dW2 0.00100752568114
# abs gradients dW1 0.000593614058078
#
# ************
# start batch 40917 iter 200
# COST 2.16955300534
# alpha 0.001
# ************
# train accuracy =  0.208
# validation set accuracy =  0.221809901324
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0200937654074
# abs gradients dW3 0.00138236884298
# abs gradients dW2 0.00115198367249
# abs gradients dW1 0.000611452484501
#
# ************
# start batch 15221 iter 220
# COST 2.13188059149
# alpha 0.001
# ************
# train accuracy =  0.24
# validation set accuracy =  0.237264906806
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0247205449233
# abs gradients dW3 0.00154777194085
# abs gradients dW2 0.00130212742723
# abs gradients dW1 0.00072133176806
#
# ************
# start batch 15477 iter 240
# COST 2.11064102233
# alpha 0.001
# ************
# train accuracy =  0.262
# validation set accuracy =  0.241439655899
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0127227320216
# abs gradients dW3 0.000923517771206
# abs gradients dW2 0.000809547071688
# abs gradients dW1 0.000456278011242
#
# ************
# start batch 24412 iter 260
# COST 2.11503929238
# alpha 0.001
# ************
# train accuracy =  0.254
# validation set accuracy =  0.242704731382
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.010848642516
# abs gradients dW3 0.000760597112832
# abs gradients dW2 0.000684626408565
# abs gradients dW1 0.000405501063604
#
# ************
# start batch 42838 iter 280
# COST 2.06505847575
# alpha 0.001
# ************
# train accuracy =  0.306
# validation set accuracy =  0.258307329004
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0170863143348
# abs gradients dW3 0.00110416298944
# abs gradients dW2 0.000893898423931
# abs gradients dW1 0.000515744182797
#
# ************
# start batch 23640 iter 300
# COST 2.09332758308
# alpha 0.001
# ************
# train accuracy =  0.268
# validation set accuracy =  0.263177869613
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0159737771092
# abs gradients dW3 0.00104213925528
# abs gradients dW2 0.000914215094656
# abs gradients dW1 0.000481120342613
#
# ************
# start batch 27360 iter 320
# COST 2.05445621829
# alpha 0.001
# ************
# train accuracy =  0.308
# validation set accuracy =  0.26832250991
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0103297531601
# abs gradients dW3 0.000725562139475
# abs gradients dW2 0.000657319827512
# abs gradients dW1 0.00043541913584
#
# ************
# start batch 12877 iter 340
# COST 2.09740409177
# alpha 0.001
# ************
# train accuracy =  0.262
# validation set accuracy =  0.264527283461
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0150056028172
# abs gradients dW3 0.00101378096804
# abs gradients dW2 0.000888139796547
# abs gradients dW1 0.000546138644203
#
# ************
# start batch 8549 iter 360
# COST 2.07453365874
# alpha 0.001
# ************
# train accuracy =  0.274
# validation set accuracy =  0.273045458379
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.013392201067
# abs gradients dW3 0.000949025737078
# abs gradients dW2 0.000847763094239
# abs gradients dW1 0.000435337290329
#
# ************
# start batch 6864 iter 380
# COST 2.05313170566
# alpha 0.001
# ************
# train accuracy =  0.254
# validation set accuracy =  0.277684068483
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0160679383321
# abs gradients dW3 0.001041586053
# abs gradients dW2 0.00088773704404
# abs gradients dW1 0.000492257493621
#
# ************
# start batch 30320 iter 400
# COST 2.07880952293
# alpha 0.0005
# ************
# train accuracy =  0.282
# validation set accuracy =  0.274900902421
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0102078271234
# abs gradients dW3 0.000736969459586
# abs gradients dW2 0.00066405646732
# abs gradients dW1 0.000420314285744
#
# ************
# start batch 46549 iter 420
# COST 2.05091817519
# alpha 0.0005
# ************
# train accuracy =  0.284
# validation set accuracy =  0.277557560934
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0161028970199
# abs gradients dW3 0.00102559609925
# abs gradients dW2 0.000891855166536
# abs gradients dW1 0.000453809402994
#
# ************
# start batch 1762 iter 440
# COST 2.05552035145
# alpha 0.0005
# ************
# train accuracy =  0.272
# validation set accuracy =  0.286623935228
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0106426807399
# abs gradients dW3 0.000750455701602
# abs gradients dW2 0.000614127761651
# abs gradients dW1 0.000359544724131
# ************
# start batch 35663 iter 460
# COST 2.03534834372
# alpha 0.0005
# ************
# train accuracy =  0.278
# validation set accuracy =  0.277473222569
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0112781567172
# abs gradients dW3 0.00077219720464
# abs gradients dW2 0.000683219187827
# abs gradients dW1 0.000393779836782
#
# ************
# start batch 21732 iter 480
# COST 2.03627004754
# alpha 0.0005
# ************
# train accuracy =  0.27
# validation set accuracy =  0.287635995614
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0168780128111
# abs gradients dW3 0.00123005060488
# abs gradients dW2 0.00102405247794
# abs gradients dW1 0.000568675994454

# %%
layer_dimensions = [X_train.shape[0],4000,4000, 4000, 10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=500, alpha=.001, batch_size=500, print_every=20)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2', 'W3', 'b3', 'W4', 'b4'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 30361 iter 0
# COST 3.07129924582
# alpha 0.001
# ************
# train accuracy =  0.124
# validation set accuracy =  0.0997301172303
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.1127381091
# abs gradients dW3 0.00393097229563
# abs gradients dW2 0.00334906782705
# abs gradients dW1 0.00158580770534
#
# ************
# start batch 22515 iter 20
# COST 2.355197073
# alpha 0.001
# ************
# train accuracy =  0.086
# validation set accuracy =  0.142426414776
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0518203043415
# abs gradients dW3 0.00188771616887
# abs gradients dW2 0.00161070917825
# abs gradients dW1 0.000763632288115
#
# ************
# start batch 2683 iter 40
# COST 2.25612771086
# alpha 0.001
# ************
# train accuracy =  0.154
# validation set accuracy =  0.151682550392
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0433722262854
# abs gradients dW3 0.00137658684162
# abs gradients dW2 0.00118281471244
# abs gradients dW1 0.000571982263443
#
# ************
# start batch 28609 iter 60
# COST 2.241139248
# alpha 0.001
# ************
# train accuracy =  0.188
# validation set accuracy =  0.183520283377
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0470517709985
# abs gradients dW3 0.00155464659112
# abs gradients dW2 0.00133541327484
# abs gradients dW1 0.00065102922871
#
# ************
# start batch 34069 iter 80
# COST 2.18450472202
# alpha 0.001
# ************
# train accuracy =  0.206
# validation set accuracy =  0.190604706081
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0402688434119
# abs gradients dW3 0.00139988052349
# abs gradients dW2 0.00118906628238
# abs gradients dW1 0.000558781690298
#
# ************
# start batch 7488 iter 100
# COST 2.18712760012
# alpha 0.001
# ************
# train accuracy =  0.174
# validation set accuracy =  0.20677658767
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0453909719825
# abs gradients dW3 0.00164682793177
# abs gradients dW2 0.00137778790059
# abs gradients dW1 0.000679467178584
#
# ************
# start batch 26538 iter 120
# COST 2.14547930889
# alpha 0.001
# ************
# train accuracy =  0.204
# validation set accuracy =  0.223011723033
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0464367232861
# abs gradients dW3 0.00148149342869
# abs gradients dW2 0.0013139916181
# abs gradients dW1 0.000659355804136
#
# ************
# start batch 47139 iter 140
# COST 2.11708909112
# alpha 0.001
# ************
# train accuracy =  0.272
# validation set accuracy =  0.210360968204
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0383714911948
# abs gradients dW3 0.00128300049748
# abs gradients dW2 0.00111042300874
# abs gradients dW1 0.000540721415256
#
# ************
# start batch 4447 iter 160
# COST 2.11429599257
# alpha 0.001
# ************
# train accuracy =  0.264
# validation set accuracy =  0.191869781564
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0410237096298
# abs gradients dW3 0.00136485458673
# abs gradients dW2 0.00118116768443
# abs gradients dW1 0.000558957821758
#
# ************
# start batch 36629 iter 180
# COST 2.12345241056
# alpha 0.001
# ************
# train accuracy =  0.254
# validation set accuracy =  0.272349666863
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0364796262867
# abs gradients dW3 0.00118335581692
# abs gradients dW2 0.00101081745022
# abs gradients dW1 0.000524571408511
#
# ************
# start batch 42696 iter 200
# COST 2.07042886245
# alpha 0.001
# ************
# train accuracy =  0.244
# validation set accuracy =  0.239099266256
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0315279809301
# abs gradients dW3 0.00119599473892
# abs gradients dW2 0.0010392947129
# abs gradients dW1 0.000554135778923
#
# ************
# start batch 13645 iter 220
# COST 2.04075584741
# alpha 0.001
# ************
# train accuracy =  0.262
# validation set accuracy =  0.262861600742
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0392564455192
# abs gradients dW3 0.00134998285277
# abs gradients dW2 0.00121319565995
# abs gradients dW1 0.000621278748337
#
# ************
# start batch 38075 iter 240
# COST 2.08167216201
# alpha 0.001
# ************
# train accuracy =  0.262
# validation set accuracy =  0.294003542211
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.032479947892
# abs gradients dW3 0.00104647675515
# abs gradients dW2 0.000890768903317
# abs gradients dW1 0.00044780355212
#
# ************
# start batch 10281 iter 260
# COST 1.99996988183
# alpha 0.001
# ************
# train accuracy =  0.298
# validation set accuracy =  0.267078519018
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.026628160736
# abs gradients dW3 0.000940830985925
# abs gradients dW2 0.000816077370463
# abs gradients dW1 0.000401342983231
#
# ************
# start batch 16431 iter 280
# COST 2.08729365208
# alpha 0.001
# ************
# train accuracy =  0.268
# validation set accuracy =  0.280614826685
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0336860468035
# abs gradients dW3 0.00108084347187
# abs gradients dW2 0.000958283084819
# abs gradients dW1 0.00045488789002
#
# ************
# start batch 1343 iter 300
# COST 2.0365054794
# alpha 0.001
# ************
# train accuracy =  0.256
# validation set accuracy =  0.2223581007
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0363220683345
# abs gradients dW3 0.00124878286353
# abs gradients dW2 0.00109478717662
# abs gradients dW1 0.000532047841474
#
# ************
# start batch 42063 iter 320
# COST 2.00586328707
# alpha 0.001
# ************
# train accuracy =  0.282
# validation set accuracy =  0.285021506283
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0333971246012
# abs gradients dW3 0.0011570789112
# abs gradients dW2 0.00102839909522
# abs gradients dW1 0.000521769372661
#
# ************
# start batch 36398 iter 340
# COST 2.0051181064
# alpha 0.001
# ************
# train accuracy =  0.322
# validation set accuracy =  0.28818419499
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0259396438291
# abs gradients dW3 0.00099130834134
# abs gradients dW2 0.000858939397094
# abs gradients dW1 0.00048151103362
#
# ************
# start batch 10612 iter 360
# COST 2.04524407128
# alpha 0.001
# ************
# train accuracy =  0.292
# validation set accuracy =  0.286876950325
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0321319499997
# abs gradients dW3 0.00111935735072
# abs gradients dW2 0.000982106827917
# abs gradients dW1 0.000470250731821
#
# ************
# start batch 15380 iter 380
# COST 2.00842698549
# alpha 0.001
# ************
# train accuracy =  0.3
# validation set accuracy =  0.270346630682
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0472116794684
# abs gradients dW3 0.00154217769998
# abs gradients dW2 0.00130343290967
# abs gradients dW1 0.00068545243869
#
# ************
# start batch 46807 iter 400
# COST 1.98792894534
# alpha 0.0005
# ************
# train accuracy =  0.296
# validation set accuracy =  0.255861516404
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0293474699339
# abs gradients dW3 0.0010466067375
# abs gradients dW2 0.000927441959763
# abs gradients dW1 0.00044761354415
#
# ************
# start batch 42926 iter 420
# COST 1.96011760848
# alpha 0.0005
# ************
# train accuracy =  0.308
# validation set accuracy =  0.329046133086
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0268174883856
# abs gradients dW3 0.000886695112631
# abs gradients dW2 0.000768861893766
# abs gradients dW1 0.000403235481716
#
# ************
# start batch 43758 iter 440
# COST 1.95089201404
# alpha 0.0005
# ************
# train accuracy =  0.328
# validation set accuracy =  0.336931770262
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0107978902382
# abs gradients dW3 0.00046794760141
# abs gradients dW2 0.000425109172721
# abs gradients dW1 0.000227099566766
# ************
# start batch 20048 iter 460
# COST 1.93051535327
# alpha 0.0005
# ************
# train accuracy =  0.348
# validation set accuracy =  0.337311292907
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0164340202216
# abs gradients dW3 0.000550755191781
# abs gradients dW2 0.000508755090098
# abs gradients dW1 0.000275437431991
#
# ************
# start batch 34730 iter 480
# COST 1.93234847288
# alpha 0.0005
# ************
# train accuracy =  0.344
# validation set accuracy =  0.334232942566
# dict_keys(['dW4', 'db4', 'dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW4 0.0134045313585
# abs gradients dW3 0.000440326618661
# abs gradients dW2 0.000397656826706
# abs gradients dW1 0.000226266532922

# %%
y_predicted = NN.predict(X_test)
save_predictions('ans1-uni', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans1-uni.npy')
print(loaded_y.shape)
loaded_y[:10]

# %% [markdown]
# ## Part 2: Regularizing the neural network
# #### Add dropout and L2 regularization

# %%
NN2 = NeuralNetwork(layer_dimensions, drop_prob=.25, reg_lambda=0)

NN2.train(X_train, y_train, iters=100, alpha=0.05, batch_size=1000, print_every=1)
# Out:
# dict_keys(['layer_dimensions', 'drop_prob', 'reg_lambda', 'W1', 'b1', 'W2', 'b2', 'W3', 'b3'])
# X train shape: (3072, 50000)
# y train shape: (50000,)
#
# ************
# start batch 15097 iter 0
# COST 4.38227552561
# alpha 0.05
# ************
# train accuracy =  0.092
# validation set accuracy =  0.0996912034719
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.160780010789
# abs gradients dW2 0.00379331624844
# abs gradients dW1 0.00142146931977
#
# ************
# start batch 14784 iter 1
# COST 109.196056338
# alpha 0.05
# ************
# train accuracy =  0.105
# validation set accuracy =  0.100859622767
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.326701860722
# abs gradients dW2 0.0116309957645
# abs gradients dW1 0.00558992890991
#
# ************
# start batch 35837 iter 2
# COST 61.6437142745
# alpha 0.05
# ************
# train accuracy =  0.095
# validation set accuracy =  0.0999207144049
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.131902462972
# abs gradients dW2 0.00584796567615
# abs gradients dW1 0.0043485897226
#
# ************
# start batch 46981 iter 3
# COST 28.8336731632
# alpha 0.05
# ************
# train accuracy =  0.099
# validation set accuracy =  0.103405107661
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0580906556035
# abs gradients dW2 0.00301252348975
# abs gradients dW1 0.00283672692132
#
# ************
# start batch 9801 iter 4
# COST 9.68564740439
# alpha 0.05
# ************
# train accuracy =  0.108
# validation set accuracy =  0.105950592555
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.0205936641558
# abs gradients dW2 0.000993177257006
# abs gradients dW1 0.00115150136736
#
# ************
# start batch 31624 iter 5
# COST 5.04435565496
# alpha 0.05
# ************
# train accuracy =  0.096
# validation set accuracy =  0.101172592222
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00826023723743
# abs gradients dW2 0.000514895560604
# abs gradients dW1 0.000779377904413
#
# ************
# start batch 36375 iter 6
# COST 2.39738807995
# alpha 0.05
# ************
# train accuracy =  0.105
# validation set accuracy =  0.121661659155
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00135677194555
# abs gradients dW2 0.000111383621247
# abs gradients dW1 0.000124623667903
#
# ************
# start batch 32189 iter 7
# COST 2.32104244031
# alpha 0.05
# ************
# train accuracy =  0.129
# validation set accuracy =  0.119888165582
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.000832953986448
# abs gradients dW2 7.68664962404e-05
# abs gradients dW1 7.07458062245e-05
#
# ************
# start batch 46571 iter 8
# COST 2.32615793372
# alpha 0.05
# ************
# train accuracy =  0.126
# validation set accuracy =  0.12646052412
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.000808627785601
# abs gradients dW2 7.67476685357e-05
# abs gradients dW1 7.0075592408e-05
#
# ************
# start batch 29692 iter 9
# COST 2.31651939362
# alpha 0.05
# ************
# train accuracy =  0.117
# validation set accuracy =  0.129924052746
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.00081876343461
# abs gradients dW2 7.64082535078e-05
# abs gradients dW1 7.05841730614e-05
#
# ************
# start batch 36682 iter 10
# COST 2.2787824717
# alpha 0.05
# ************
# train accuracy =  0.146
# validation set accuracy =  0.133471039893
# dict_keys(['dW3', 'db3', 'dW2', 'db2', 'dW1', 'db1'])
# abs gradients dW3 0.000667677218999
# abs gradients dW2 6.51970902945e-05
# abs gradients dW1 6.30420124253e-05
#
# ************
# start batch 4125

# %%
y_predicted2 = NN2.predict(X)
save_predictions(y_predicted, 'ans2-uni')

# %%
layer_dimensions
# Out:
# [3072, 3072, 3072, 10]

# %%
T = one_hot(test)
T

# %%
np.random.randint(10)
# Out:
# 3
